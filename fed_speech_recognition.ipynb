# %%
# !pip install git+https://github.com/openai/whisper.git

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3080 Ti (UUID: GPU-94e91653-0ae4-9d0a-2ff5-73b5b1fcef5a)

# %%
# whisper --help | findstr -i pytorch
# !whisper --help | findstr -i pytorch
# Out:
#   --device DEVICE       device to use for PyTorch inference (default: cuda)

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
import torchaudio
torchaudio.__version__

# %%
import whisper
from pytube import YouTube

# %% [markdown]
# models include

# %% [markdown]
# | size | parameters | english-only model | multilingual model |
# |------|------------|--------------------|--------------------|
# | tiny | 39 M       | Y                  | Y                  |
# | base | 74 M       | Y | Y |
# | small | 244 M | Y | Y |
# | medium | 769 M | Y | Y |
# | large | 155 M | N | Y |

# %%
# choose model type to use
model = whisper.load_model('base', device='cuda')

# %%
youtube_video_url = "https://www.youtube.com/watch?v=NT2H9iyd-ms"
youtube_video = YouTube(youtube_video_url)

# %%
youtube_video.title
# Out:
# 'WATCH LIVE | Fed Chair Powell Discusses Latest Fed Rate Hike'

# %%
youtube_video.streams
# Out:
# [<Stream: itag="17" mime_type="video/3gpp" res="144p" fps="7fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">, <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">, <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
for stream in youtube_video.streams:
    print(stream)
# Out:
# <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="7fps" vcodec="mp4v.20.3" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">
# <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="30fps" vcodec="avc1.640028" progressive="False" type="video">
# <Stream: itag="248" mime_type="video/webm" res="1080p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="136" mime_type="video/mp4" res="720p" fps="30fps" vcodec="avc1.64001f" progressive="False" type="video">
# <Stream: itag="247" mime_type="video/webm" res="720p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401f" progressive="False" type="video">
# <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e" progressive="False" type="video">
# <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">
# <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">
# <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9" progressive="False" type="video">
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">
# <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">
# <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">
# <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">
# <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.first()
stream
# Out:
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">

# %%
# there shouldn't be much audio noise so we're just going to use the first stream with an abr of "48kbps"

# %%
stream.download(filename="fed_meeting.mp4")
# Out:
# 'c:\\Users\\Emanuel\\PycharmProjects\\Develop\\gpt-investment-app\\fed_meeting.mp4'

# %% [markdown]
# To do some cleaning and cut out the crap at the beginning of the video: (by using ffmpeg)

# %%
# !ffmpeg -ss 378 -i fed_meeting.mp4 -t 2715 fed_meeting_trimmed.mp4
# Out:
# ^C

# %%
import datetime

# save a timestamp before trancription
t1 = datetime.datetime.now()
print(f"started at {t1}")

# do the transcription
output = model.transcribe("fed_meeting_trimmed.mp4")

# show time elapsed after transcription is complete
t2 = datetime.datetime.now()
print("ended at {t2}")
print(f"time elapsed: {t2 - t1}")
# Out:
# started at 2023-06-11 20:12:19.531810
# ended at {t2}
# time elapsed: 0:02:49.108152

# %%
output
# Out:
# {'text': " Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal. We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses. Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy. Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all. Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate. We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%. In addition, we are continuing the process of significantly reducing the size of our balance sheet. Restoring price stability will likely require maintaining a restrictive stance of policy for some time. I will have more to say about today's monetary policy actions after briefly reviewing economic developments. The U.S. economy has slowed significantly from last year's rapid pace. Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year. Recent indicators point to modest growth of spending and production this quarter. Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions. Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates. Higher interest rates and slower output growth also appear to be weighing on business fixed investment. Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low. Job vacancies still very high and wage growth elevated. Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September. Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers. The labor force participation rate is little changed since the beginning of the year. Inflation remains well above our longer run goal of 2%. Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%. And the recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services. Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation. Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters, as well as measures from financial markets. But that is not grounds for complacency. The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched. The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people. My colleagues and I are acutely aware that high inflation imposes significant hardship and as it erodes purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation. We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective. At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points. And we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in affirming the stance of ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 8.0,
#    'text': ' Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal.',
#    'tokens': [50364,
#     2205,
#     6499,
#     13,
#     1222,
#     7734,
#     293,
#     286,
#     366,
#     10613,
#     7784,
#     281,
#     5062,
#     15860,
#     646,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     13,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.14292316179017764,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247255206108093},
#   {'id': 1,
#    'seek': 0,
#    'start': 8.0,
#    'end': 16.0,
#    'text': ' We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses.',
#    'tokens': [50764,
#     492,
#     362,
#     1293,
#     264,
#     3873,
#     300,
#     321,
#     643,
#     293,
#     264,
#     14151,
#     309,
#     486,
#     747,
#     281,
#     15227,
#     3218,
#     11826,
#     322,
#     9490,
#     295,
#     2665,
#     4466,
#     293,
#     6011,
#     13,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.14292316179017764,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247255206108093},
#   {'id': 2,
#    'seek': 0,
#    'start': 16.0,
#    'end': 22.0,
#    'text': ' Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy.',
#    'tokens': [51164,
#     25803,
#     11826,
#     307,
#     264,
#     6357,
#     295,
#     264,
#     12380,
#     26049,
#     293,
#     13451,
#     382,
#     264,
#     2901,
#     17799,
#     295,
#     527,
#     5010,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.14292316179017764,
#    'compression_ratio': 1.5818181818181818,
#    'no_speech_prob': 0.06247255206108093},
#   {'id': 3,
#    'seek': 2200,
#    'start': 23.0,
#    'end': 26.0,
#    'text': ' Without price stability, the economy does not work for anyone.',
#    'tokens': [50414,
#     9129,
#     3218,
#     11826,
#     11,
#     264,
#     5010,
#     775,
#     406,
#     589,
#     337,
#     2878,
#     13,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.09485793794904436,
#    'compression_ratio': 1.5251141552511416,
#    'no_speech_prob': 0.4874759614467621},
#   {'id': 4,
#    'seek': 2200,
#    'start': 26.0,
#    'end': 34.0,
#    'text': ' In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all.',
#    'tokens': [50564,
#     682,
#     1729,
#     11,
#     1553,
#     3218,
#     11826,
#     11,
#     321,
#     486,
#     406,
#     4584,
#     257,
#     23389,
#     2896,
#     295,
#     2068,
#     5938,
#     2142,
#     4487,
#     300,
#     5121,
#     439,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.09485793794904436,
#    'compression_ratio': 1.5251141552511416,
#    'no_speech_prob': 0.4874759614467621},
#   {'id': 5,
#    'seek': 2200,
#    'start': 36.0,
#    'end': 45.0,
#    'text': ' Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate.',
#    'tokens': [51064,
#     2692,
#     11,
#     264,
#     479,
#     5251,
#     34,
#     6005,
#     527,
#     3897,
#     1179,
#     3314,
#     538,
#     9562,
#     5143,
#     2793,
#     293,
#     321,
#     2354,
#     281,
#     21685,
#     300,
#     10452,
#     8637,
#     486,
#     312,
#     6854,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.09485793794904436,
#    'compression_ratio': 1.5251141552511416,
#    'no_speech_prob': 0.4874759614467621},
#   {'id': 6,
#    'seek': 4500,
#    'start': 46.0,
#    'end': 52.0,
#    'text': ' We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%.',
#    'tokens': [50414,
#     492,
#     366,
#     2684,
#     527,
#     3897,
#     21033,
#     4334,
#     2277,
#     281,
#     257,
#     1496,
#     300,
#     486,
#     312,
#     31868,
#     43220,
#     281,
#     2736,
#     15860,
#     281,
#     568,
#     6856,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.07955877079683192,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.2582671344280243},
#   {'id': 7,
#    'seek': 4500,
#    'start': 52.0,
#    'end': 57.0,
#    'text': ' In addition, we are continuing the process of significantly reducing the size of our balance sheet.',
#    'tokens': [50714,
#     682,
#     4500,
#     11,
#     321,
#     366,
#     9289,
#     264,
#     1399,
#     295,
#     10591,
#     12245,
#     264,
#     2744,
#     295,
#     527,
#     4772,
#     8193,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.07955877079683192,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.2582671344280243},
#   {'id': 8,
#    'seek': 4500,
#    'start': 57.0,
#    'end': 64.0,
#    'text': ' Restoring price stability will likely require maintaining a restrictive stance of policy for some time.',
#    'tokens': [50964,
#     13094,
#     3662,
#     3218,
#     11826,
#     486,
#     3700,
#     3651,
#     14916,
#     257,
#     43220,
#     21033,
#     295,
#     3897,
#     337,
#     512,
#     565,
#     13,
#     51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.07955877079683192,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.2582671344280243},
#   {'id': 9,
#    'seek': 4500,
#    'start': 64.0,
#    'end': 71.0,
#    'text': " I will have more to say about today's monetary policy actions after briefly reviewing economic developments.",
#    'tokens': [51314,
#     286,
#     486,
#     362,
#     544,
#     281,
#     584,
#     466,
#     965,
#     311,
#     26388,
#     3897,
#     5909,
#     934,
#     10515,
#     19576,
#     4836,
#     20862,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.07955877079683192,
#    'compression_ratio': 1.6526717557251909,
#    'no_speech_prob': 0.2582671344280243},
#   {'id': 10,
#    'seek': 7100,
#    'start': 72.0,
#    'end': 77.0,
#    'text': " The U.S. economy has slowed significantly from last year's rapid pace.",
#    'tokens': [50414,
#     440,
#     624,
#     13,
#     50,
#     13,
#     5010,
#     575,
#     32057,
#     10591,
#     490,
#     1036,
#     1064,
#     311,
#     7558,
#     11638,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.10786630993797666,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.2946016490459442},
#   {'id': 11,
#    'seek': 7100,
#    'start': 77.0,
#    'end': 84.0,
#    'text': ' Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year.',
#    'tokens': [50664,
#     8467,
#     19599,
#     10895,
#     412,
#     257,
#     11638,
#     295,
#     568,
#     13,
#     21,
#     4,
#     1036,
#     6555,
#     457,
#     307,
#     44553,
#     370,
#     1400,
#     341,
#     1064,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.10786630993797666,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.2946016490459442},
#   {'id': 12,
#    'seek': 7100,
#    'start': 84.0,
#    'end': 89.0,
#    'text': ' Recent indicators point to modest growth of spending and production this quarter.',
#    'tokens': [51014,
#     17553,
#     22176,
#     935,
#     281,
#     25403,
#     4599,
#     295,
#     6434,
#     293,
#     4265,
#     341,
#     6555,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.10786630993797666,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.2946016490459442},
#   {'id': 13,
#    'seek': 7100,
#    'start': 89.0,
#    'end': 98.0,
#    'text': " Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions.",
#    'tokens': [51264,
#     48345,
#     294,
#     9711,
#     6434,
#     575,
#     32057,
#     490,
#     1036,
#     1064,
#     311,
#     7558,
#     11638,
#     294,
#     644,
#     23543,
#     3126,
#     957,
#     41578,
#     5742,
#     293,
#     30443,
#     4669,
#     4487,
#     13,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.10786630993797666,
#    'compression_ratio': 1.6422413793103448,
#    'no_speech_prob': 0.2946016490459442},
#   {'id': 14,
#    'seek': 9800,
#    'start': 99.0,
#    'end': 105.0,
#    'text': ' Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates.',
#    'tokens': [50414,
#     3251,
#     4253,
#     294,
#     264,
#     6849,
#     6977,
#     575,
#     42613,
#     10591,
#     11,
#     11611,
#     23543,
#     2946,
#     20236,
#     6846,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.13004178267258865,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.45754656195640564},
#   {'id': 15,
#    'seek': 9800,
#    'start': 105.0,
#    'end': 112.0,
#    'text': ' Higher interest rates and slower output growth also appear to be weighing on business fixed investment.',
#    'tokens': [50714,
#     31997,
#     1179,
#     6846,
#     293,
#     14009,
#     5598,
#     4599,
#     611,
#     4204,
#     281,
#     312,
#     31986,
#     322,
#     1606,
#     6806,
#     6078,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.13004178267258865,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.45754656195640564},
#   {'id': 16,
#    'seek': 9800,
#    'start': 112.0,
#    'end': 119.0,
#    'text': ' Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low.',
#    'tokens': [51064,
#     11334,
#     264,
#     2964,
#     5093,
#     294,
#     4599,
#     11,
#     264,
#     5938,
#     2142,
#     7023,
#     4664,
#     4524,
#     365,
#     264,
#     17438,
#     3314,
#     412,
#     257,
#     2625,
#     12,
#     5294,
#     2295,
#     13,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.13004178267258865,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.45754656195640564},
#   {'id': 17,
#    'seek': 9800,
#    'start': 119.0,
#    'end': 124.0,
#    'text': ' Job vacancies still very high and wage growth elevated.',
#    'tokens': [51414,
#     18602,
#     2842,
#     32286,
#     920,
#     588,
#     1090,
#     293,
#     15444,
#     4599,
#     23457,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.13004178267258865,
#    'compression_ratio': 1.542857142857143,
#    'no_speech_prob': 0.45754656195640564},
#   {'id': 18,
#    'seek': 12400,
#    'start': 125.0,
#    'end': 133.0,
#    'text': ' Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September.',
#    'tokens': [50414,
#     18602,
#     16823,
#     362,
#     668,
#     13956,
#     365,
#     11949,
#     11636,
#     538,
#     364,
#     4274,
#     295,
#     7562,
#     24,
#     11,
#     1360,
#     4782,
#     680,
#     1618,
#     670,
#     6897,
#     293,
#     7216,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.07048813716785328,
#    'compression_ratio': 1.5108225108225108,
#    'no_speech_prob': 0.05785762518644333},
#   {'id': 19,
#    'seek': 12400,
#    'start': 133.0,
#    'end': 148.0,
#    'text': ' Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers.',
#    'tokens': [50814,
#     5780,
#     1691,
#     2842,
#     32286,
#     362,
#     4259,
#     2507,
#     641,
#     29687,
#     293,
#     264,
#     11638,
#     295,
#     1691,
#     16823,
#     575,
#     32057,
#     490,
#     3071,
#     294,
#     264,
#     1064,
#     11,
#     264,
#     5938,
#     2142,
#     6515,
#     281,
#     312,
#     484,
#     295,
#     4772,
#     11,
#     365,
#     4733,
#     30797,
#     14048,
#     278,
#     264,
#     5847,
#     295,
#     2435,
#     5600,
#     13,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.07048813716785328,
#    'compression_ratio': 1.5108225108225108,
#    'no_speech_prob': 0.05785762518644333},
#   {'id': 20,
#    'seek': 14800,
#    'start': 148.0,
#    'end': 153.0,
#    'text': ' The labor force participation rate is little changed since the beginning of the year.',
#    'tokens': [50364,
#     440,
#     5938,
#     3464,
#     13487,
#     3314,
#     307,
#     707,
#     3105,
#     1670,
#     264,
#     2863,
#     295,
#     264,
#     1064,
#     13,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.13766849040985107,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.43322715163230896},
#   {'id': 21,
#    'seek': 14800,
#    'start': 153.0,
#    'end': 158.0,
#    'text': ' Inflation remains well above our longer run goal of 2%.',
#    'tokens': [50614,
#     682,
#     3423,
#     399,
#     7023,
#     731,
#     3673,
#     527,
#     2854,
#     1190,
#     3387,
#     295,
#     568,
#     6856,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.13766849040985107,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.43322715163230896},
#   {'id': 22,
#    'seek': 14800,
#    'start': 158.0,
#    'end': 169.0,
#    'text': ' Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%.',
#    'tokens': [50864,
#     4886,
#     264,
#     2272,
#     2493,
#     8121,
#     294,
#     7216,
#     11,
#     3217,
#     6465,
#     36,
#     7901,
#     10895,
#     412,
#     1386,
#     13,
#     17,
#     8923,
#     49999,
#     264,
#     34377,
#     1755,
#     293,
#     2281,
#     10479,
#     11,
#     4965,
#     6465,
#     36,
#     7901,
#     10895,
#     412,
#     1025,
#     13,
#     16,
#     6856,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.13766849040985107,
#    'compression_ratio': 1.4577114427860696,
#    'no_speech_prob': 0.43322715163230896},
#   {'id': 23,
#    'seek': 16900,
#    'start': 170.0,
#    'end': 174.0,
#    'text': ' And the recent inflation data again have come in higher than expected.',
#    'tokens': [50414,
#     400,
#     264,
#     5162,
#     15860,
#     1412,
#     797,
#     362,
#     808,
#     294,
#     2946,
#     813,
#     5176,
#     13,
#     50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.10541546999753176,
#    'compression_ratio': 1.7056603773584906,
#    'no_speech_prob': 0.8328478932380676},
#   {'id': 24,
#    'seek': 16900,
#    'start': 174.0,
#    'end': 178.0,
#    'text': ' Price pressures remained evident across a broad range of goods and services.',
#    'tokens': [50614,
#     25803,
#     23573,
#     12780,
#     16371,
#     2108,
#     257,
#     4152,
#     3613,
#     295,
#     10179,
#     293,
#     3328,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.10541546999753176,
#    'compression_ratio': 1.7056603773584906,
#    'no_speech_prob': 0.8328478932380676},
#   {'id': 25,
#    'seek': 16900,
#    'start': 178.0,
#    'end': 186.0,
#    'text': " Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation.",
#    'tokens': [50814,
#     6797,
#     311,
#     1516,
#     1970,
#     14081,
#     575,
#     9194,
#     292,
#     7901,
#     337,
#     2281,
#     293,
#     1755,
#     293,
#     575,
#     2942,
#     4497,
#     23452,
#     3321,
#     322,
#     15860,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.10541546999753176,
#    'compression_ratio': 1.7056603773584906,
#    'no_speech_prob': 0.8328478932380676},
#   {'id': 26,
#    'seek': 16900,
#    'start': 186.0,
#    'end': 198.0,
#    'text': ' Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters,',
#    'tokens': [51214,
#     11334,
#     23457,
#     15860,
#     11,
#     2854,
#     1433,
#     15860,
#     9843,
#     4204,
#     281,
#     6222,
#     731,
#     12723,
#     2769,
#     11,
#     382,
#     15502,
#     294,
#     257,
#     4152,
#     3613,
#     295,
#     22711,
#     295,
#     22850,
#     11,
#     6011,
#     11,
#     293,
#     2091,
#     16369,
#     1559,
#     11,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.10541546999753176,
#    'compression_ratio': 1.7056603773584906,
#    'no_speech_prob': 0.8328478932380676},
#   {'id': 27,
#    'seek': 19800,
#    'start': 198.0,
#    'end': 201.0,
#    'text': ' as well as measures from financial markets.',
#    'tokens': [50364, 382, 731, 382, 8000, 490, 4669, 8383, 13, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.06573963165283203,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.12082453817129135},
#   {'id': 28,
#    'seek': 19800,
#    'start': 201.0,
#    'end': 204.0,
#    'text': ' But that is not grounds for complacency.',
#    'tokens': [50514, 583, 300, 307, 406, 19196, 337, 49546, 3020, 13, 50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.06573963165283203,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.12082453817129135},
#   {'id': 29,
#    'seek': 19800,
#    'start': 204.0,
#    'end': 212.0,
#    'text': ' The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched.',
#    'tokens': [50664,
#     440,
#     2854,
#     264,
#     2190,
#     2372,
#     295,
#     1090,
#     15860,
#     6515,
#     11,
#     264,
#     5044,
#     264,
#     2931,
#     300,
#     9843,
#     295,
#     2946,
#     15860,
#     486,
#     1813,
#     948,
#     42388,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.06573963165283203,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.12082453817129135},
#   {'id': 30,
#    'seek': 19800,
#    'start': 212.0,
#    'end': 220.0,
#    'text': " The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people.",
#    'tokens': [51064,
#     440,
#     7772,
#     311,
#     26388,
#     3897,
#     5909,
#     366,
#     19663,
#     538,
#     527,
#     23885,
#     281,
#     9773,
#     6674,
#     11949,
#     293,
#     8351,
#     7901,
#     337,
#     264,
#     2665,
#     561,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.06573963165283203,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.12082453817129135},
#   {'id': 31,
#    'seek': 22000,
#    'start': 221.0,
#    'end': 235.0,
#    'text': ' My colleagues and I are acutely aware that high inflation imposes significant hardship and as it erodes purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation.',
#    'tokens': [50414,
#     1222,
#     7734,
#     293,
#     286,
#     366,
#     696,
#     325,
#     736,
#     3650,
#     300,
#     1090,
#     15860,
#     704,
#     4201,
#     4776,
#     24172,
#     293,
#     382,
#     309,
#     1189,
#     4789,
#     20906,
#     1347,
#     11,
#     2318,
#     337,
#     729,
#     1935,
#     1075,
#     281,
#     1677,
#     264,
#     2946,
#     5497,
#     295,
#     46884,
#     411,
#     1755,
#     11,
#     6849,
#     11,
#     293,
#     11328,
#     13,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.07810845607664527,
#    'compression_ratio': 1.6514522821576763,
#    'no_speech_prob': 0.36139461398124695},
#   {'id': 32,
#    'seek': 22000,
#    'start': 235.0,
#    'end': 246.0,
#    'text': " We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective.",
#    'tokens': [51114,
#     492,
#     366,
#     5405,
#     43661,
#     281,
#     264,
#     10888,
#     300,
#     1090,
#     15860,
#     26059,
#     281,
#     1293,
#     4881,
#     295,
#     527,
#     23885,
#     11,
#     293,
#     321,
#     434,
#     10613,
#     7784,
#     281,
#     12678,
#     15860,
#     281,
#     527,
#     568,
#     4,
#     10024,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.07810845607664527,
#    'compression_ratio': 1.6514522821576763,
#    'no_speech_prob': 0.36139461398124695},
#   {'id': 33,
#    'seek': 24600,
#    'start': 247.0,
#    'end': 253.0,
#    'text': " At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points.",
#    'tokens': [50414,
#     1711,
#     965,
#     311,
#     3440,
#     11,
#     264,
#     7482,
#     6005,
#     264,
#     3779,
#     3613,
#     337,
#     264,
#     6019,
#     8271,
#     3314,
#     538,
#     9562,
#     5143,
#     2793,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.12230360507965088,
#    'compression_ratio': 1.5751072961373391,
#    'no_speech_prob': 0.4728427231311798},
#   {'id': 34,
#    'seek': 24600,
#    'start': 253.0,
#    'end': 263.0,
#    'text': ' And we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in affirming the stance of monetary policy.',
#    'tokens': [50714,
#     400,
#     321,
#     366,
#     9289,
#     264,
#     1399,
#     295,
#     10591,
#     12245,
#     264,
#     2744,
#     295,
#     527,
#     4772,
#     8193,
#     11,
#     597,
#     5749,
#     364,
#     1021,
#     3090,
#     294,
#     36315,
#     2810,
#     264,
#     21033,
#     295,
#     26388,
#     3897,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.12230360507965088,
#    'compression_ratio': 1.5751072961373391,
#    'no_speech_prob': 0.4728427231311798},
#   {'id': 35,
#    'seek': 24600,
#    'start': 263.0,
#    'end': 268.0,
#    'text': " With today's action, we've raised interest rates by 3 and 3-quarters percentage points this year.",
#    'tokens': [51214,
#     2022,
#     965,
#     311,
#     3069,
#     11,
#     321,
#     600,
#     6005,
#     1179,
#     6846,
#     538,
#     805,
#     293,
#     805,
#     12,
#     17313,
#     9668,
#     2793,
#     341,
#     1064,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.12230360507965088,
#    'compression_ratio': 1.5751072961373391,
#    'no_speech_prob': 0.4728427231311798},
#   {'id': 36,
#    'seek': 26800,
#    'start': 268.0,
#    'end': 281.0,
#    'text': ' We anticipate that ongoing increases in the target range for the federal funds rate will be appropriate in order to attain a stance of monetary policy that is sufficiently restrictive to return inflation to 2% over time.',
#    'tokens': [50364,
#     492,
#     21685,
#     300,
#     10452,
#     8637,
#     294,
#     264,
#     3779,
#     3613,
#     337,
#     264,
#     6019,
#     8271,
#     3314,
#     486,
#     312,
#     6854,
#     294,
#     1668,
#     281,
#     23766,
#     257,
#     21033,
#     295,
#     26388,
#     3897,
#     300,
#     307,
#     31868,
#     43220,
#     281,
#     2736,
#     15860,
#     281,
#     568,
#     4,
#     670,
#     565,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.0632320761680603,
#    'compression_ratio': 1.6484375,
#    'no_speech_prob': 0.37917807698249817},
#   {'id': 37,
#    'seek': 26800,
#    'start': 281.0,
#    'end': 291.0,
#    'text': ' Financial conditions have tightened significantly in response to our policy actions, and we are seeing the effects on demand in the most interest rate sensitive sectors of the economy, such as housing.',
#    'tokens': [51014,
#     25560,
#     4487,
#     362,
#     49673,
#     10591,
#     294,
#     4134,
#     281,
#     527,
#     3897,
#     5909,
#     11,
#     293,
#     321,
#     366,
#     2577,
#     264,
#     5065,
#     322,
#     4733,
#     294,
#     264,
#     881,
#     1179,
#     3314,
#     9477,
#     18373,
#     295,
#     264,
#     5010,
#     11,
#     1270,
#     382,
#     6849,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.0632320761680603,
#    'compression_ratio': 1.6484375,
#    'no_speech_prob': 0.37917807698249817},
#   {'id': 38,
#    'seek': 29100,
#    'start': 292.0,
#    'end': 298.0,
#    'text': ' It will take time, however, for the full effects of monetary restraint to be realized, especially on inflation.',
#    'tokens': [50414,
#     467,
#     486,
#     747,
#     565,
#     11,
#     4461,
#     11,
#     337,
#     264,
#     1577,
#     5065,
#     295,
#     26388,
#     49281,
#     281,
#     312,
#     5334,
#     11,
#     2318,
#     322,
#     15860,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.056741231196635475,
#    'compression_ratio': 1.6727272727272726,
#    'no_speech_prob': 0.38531485199928284},
#   {'id': 39,
#    'seek': 29100,
#    'start': 298.0,
#    'end': 312.0,
#    'text': " That's why we say in our statement that in determining the pace of future increases in the target range, we will take into account the cumulative tightening of monetary policy and the lags with which monetary policy affects economic activity and inflation.",
#    'tokens': [50714,
#     663,
#     311,
#     983,
#     321,
#     584,
#     294,
#     527,
#     5629,
#     300,
#     294,
#     23751,
#     264,
#     11638,
#     295,
#     2027,
#     8637,
#     294,
#     264,
#     3779,
#     3613,
#     11,
#     321,
#     486,
#     747,
#     666,
#     2696,
#     264,
#     38379,
#     42217,
#     295,
#     26388,
#     3897,
#     293,
#     264,
#     8953,
#     82,
#     365,
#     597,
#     26388,
#     3897,
#     11807,
#     4836,
#     5191,
#     293,
#     15860,
#     13,
#     51414],
#    'temperature': 0.0,
#    'avg_logprob': -0.056741231196635475,
#    'compression_ratio': 1.6727272727272726,
#    'no_speech_prob': 0.38531485199928284},
#   {'id': 40,
#    'seek': 31200,
#    'start': 313.0,
#    'end': 326.0,
#    'text': " At some point, as I've said in the last two press conferences, it will become appropriate to slow the pace of increases as we approach the level of interest rates that will be sufficiently restrictive to bring inflation down to our 2% goal.",
#    'tokens': [50414,
#     1711,
#     512,
#     935,
#     11,
#     382,
#     286,
#     600,
#     848,
#     294,
#     264,
#     1036,
#     732,
#     1886,
#     22032,
#     11,
#     309,
#     486,
#     1813,
#     6854,
#     281,
#     2964,
#     264,
#     11638,
#     295,
#     8637,
#     382,
#     321,
#     3109,
#     264,
#     1496,
#     295,
#     1179,
#     6846,
#     300,
#     486,
#     312,
#     31868,
#     43220,
#     281,
#     1565,
#     15860,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.06257445995624249,
#    'compression_ratio': 1.597938144329897,
#    'no_speech_prob': 0.6985467076301575},
#   {'id': 41,
#    'seek': 31200,
#    'start': 326.0,
#    'end': 330.0,
#    'text': ' There is significant uncertainty around that level of interest rates.',
#    'tokens': [51064,
#     821,
#     307,
#     4776,
#     15697,
#     926,
#     300,
#     1496,
#     295,
#     1179,
#     6846,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.06257445995624249,
#    'compression_ratio': 1.597938144329897,
#    'no_speech_prob': 0.6985467076301575},
#   {'id': 42,
#    'seek': 33000,
#    'start': 330.0,
#    'end': 342.0,
#    'text': ' Even so, we still have some ways to go, and incoming data since our last meeting suggests that the ultimate level of interest rates will be higher than previously expected.',
#    'tokens': [50364,
#     2754,
#     370,
#     11,
#     321,
#     920,
#     362,
#     512,
#     2098,
#     281,
#     352,
#     11,
#     293,
#     22341,
#     1412,
#     1670,
#     527,
#     1036,
#     3440,
#     13409,
#     300,
#     264,
#     9705,
#     1496,
#     295,
#     1179,
#     6846,
#     486,
#     312,
#     2946,
#     813,
#     8046,
#     5176,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.07905572293752647,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.6279720067977905},
#   {'id': 43,
#    'seek': 33000,
#    'start': 342.0,
#    'end': 349.0,
#    'text': ' Our decisions will depend on the totality of incoming data and their implications for the outlook for economic activity and inflation.',
#    'tokens': [50964,
#     2621,
#     5327,
#     486,
#     5672,
#     322,
#     264,
#     1993,
#     1860,
#     295,
#     22341,
#     1412,
#     293,
#     641,
#     16602,
#     337,
#     264,
#     26650,
#     337,
#     4836,
#     5191,
#     293,
#     15860,
#     13,
#     51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.07905572293752647,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.6279720067977905},
#   {'id': 44,
#    'seek': 33000,
#    'start': 349.0,
#    'end': 354.0,
#    'text': ' We will continue to make our decisions meeting by being and communicate our thinking as clearly as possible.',
#    'tokens': [51314,
#     492,
#     486,
#     2354,
#     281,
#     652,
#     527,
#     5327,
#     3440,
#     538,
#     885,
#     293,
#     7890,
#     527,
#     1953,
#     382,
#     4448,
#     382,
#     1944,
#     13,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.07905572293752647,
#    'compression_ratio': 1.7049180327868851,
#    'no_speech_prob': 0.6279720067977905},
#   {'id': 45,
#    'seek': 35400,
#    'start': 355.0,
#    'end': 360.0,
#    'text': " We're taking forceful steps to moderate demand so that it comes into better alignment with supply.",
#    'tokens': [50414,
#     492,
#     434,
#     1940,
#     3464,
#     906,
#     4439,
#     281,
#     18174,
#     4733,
#     370,
#     300,
#     309,
#     1487,
#     666,
#     1101,
#     18515,
#     365,
#     5847,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.06982149051714547,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.5722406506538391},
#   {'id': 46,
#    'seek': 35400,
#    'start': 360.0,
#    'end': 369.0,
#    'text': ' Our overarching focus is using our tools to bring inflation back down to our 2% goal and to keep longer term inflation expectations well anchored.',
#    'tokens': [50664,
#     2621,
#     45501,
#     1879,
#     307,
#     1228,
#     527,
#     3873,
#     281,
#     1565,
#     15860,
#     646,
#     760,
#     281,
#     527,
#     568,
#     4,
#     3387,
#     293,
#     281,
#     1066,
#     2854,
#     1433,
#     15860,
#     9843,
#     731,
#     12723,
#     2769,
#     13,
#     51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.06982149051714547,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.5722406506538391},
#   {'id': 47,
#    'seek': 35400,
#    'start': 369.0,
#    'end': 378.0,
#    'text': ' Reducing inflation is likely to require a sustained period of below trend growth and some softening of labor market conditions.',
#    'tokens': [51114,
#     4477,
#     1311,
#     278,
#     15860,
#     307,
#     3700,
#     281,
#     3651,
#     257,
#     23389,
#     2896,
#     295,
#     2507,
#     6028,
#     4599,
#     293,
#     512,
#     2787,
#     4559,
#     295,
#     5938,
#     2142,
#     4487,
#     13,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.06982149051714547,
#    'compression_ratio': 1.5872340425531914,
#    'no_speech_prob': 0.5722406506538391},
#   {'id': 48,
#    'seek': 37800,
#    'start': 379.0,
#    'end': 386.0,
#    'text': ' Restoring price stability is essential to set the stage for achieving maximum employment and stable prices in the longer run.',
#    'tokens': [50414,
#     13094,
#     3662,
#     3218,
#     11826,
#     307,
#     7115,
#     281,
#     992,
#     264,
#     3233,
#     337,
#     19626,
#     6674,
#     11949,
#     293,
#     8351,
#     7901,
#     294,
#     264,
#     2854,
#     1190,
#     13,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.06328221573226753,
#    'compression_ratio': 1.6031128404669261,
#    'no_speech_prob': 0.7887825965881348},
#   {'id': 49,
#    'seek': 37800,
#    'start': 386.0,
#    'end': 391.0,
#    'text': ' The historical record caution strongly against prematurely loosening policy.',
#    'tokens': [50764,
#     440,
#     8584,
#     2136,
#     23585,
#     10613,
#     1970,
#     34877,
#     356,
#     40454,
#     4559,
#     3897,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.06328221573226753,
#    'compression_ratio': 1.6031128404669261,
#    'no_speech_prob': 0.7887825965881348},
#   {'id': 50,
#    'seek': 37800,
#    'start': 391.0,
#    'end': 394.0,
#    'text': ' We will stay the course until the job is done.',
#    'tokens': [51014,
#     492,
#     486,
#     1754,
#     264,
#     1164,
#     1826,
#     264,
#     1691,
#     307,
#     1096,
#     13,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.06328221573226753,
#    'compression_ratio': 1.6031128404669261,
#    'no_speech_prob': 0.7887825965881348},
#   {'id': 51,
#    'seek': 37800,
#    'start': 394.0,
#    'end': 400.0,
#    'text': ' To conclude, we understand that our actions affect communities, families, and businesses across the country.',
#    'tokens': [51164,
#     1407,
#     16886,
#     11,
#     321,
#     1223,
#     300,
#     527,
#     5909,
#     3345,
#     4456,
#     11,
#     4466,
#     11,
#     293,
#     6011,
#     2108,
#     264,
#     1941,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.06328221573226753,
#    'compression_ratio': 1.6031128404669261,
#    'no_speech_prob': 0.7887825965881348},
#   {'id': 52,
#    'seek': 37800,
#    'start': 400.0,
#    'end': 404.0,
#    'text': ' Everything we do is in service to our public mission.',
#    'tokens': [51464,
#     5471,
#     321,
#     360,
#     307,
#     294,
#     2643,
#     281,
#     527,
#     1908,
#     4447,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.06328221573226753,
#    'compression_ratio': 1.6031128404669261,
#    'no_speech_prob': 0.7887825965881348},
#   {'id': 53,
#    'seek': 40400,
#    'start': 405.0,
#    'end': 410.0,
#    'text': ' We at the Fed will do everything we can to achieve our maximum employment and price stability goals.',
#    'tokens': [50414,
#     492,
#     412,
#     264,
#     7772,
#     486,
#     360,
#     1203,
#     321,
#     393,
#     281,
#     4584,
#     527,
#     6674,
#     11949,
#     293,
#     3218,
#     11826,
#     5493,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 54,
#    'seek': 40400,
#    'start': 410.0,
#    'end': 413.0,
#    'text': ' Thank you and I look forward to your questions.',
#    'tokens': [50664,
#     1044,
#     291,
#     293,
#     286,
#     574,
#     2128,
#     281,
#     428,
#     1651,
#     13,
#     50814],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 55,
#    'seek': 40400,
#    'start': 413.0,
#    'end': 416.0,
#    'text': ' Thank you, Colby.',
#    'tokens': [50814, 1044, 291, 11, 4004, 2322, 13, 50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 56,
#    'seek': 40400,
#    'start': 418.0,
#    'end': 420.0,
#    'text': ' Thank you, Colby Smith with the Financial Times.',
#    'tokens': [51064,
#     1044,
#     291,
#     11,
#     4004,
#     2322,
#     8538,
#     365,
#     264,
#     25560,
#     11366,
#     13,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 57,
#    'seek': 40400,
#    'start': 420.0,
#    'end': 423.0,
#    'text': ' On the need to slow the pace of rate increases at some point.',
#    'tokens': [51164,
#     1282,
#     264,
#     643,
#     281,
#     2964,
#     264,
#     11638,
#     295,
#     3314,
#     8637,
#     412,
#     512,
#     935,
#     13,
#     51314],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 58,
#    'seek': 40400,
#    'start': 423.0,
#    'end': 431.0,
#    'text': " Is a downshift contingent on a string of better inflation data specifically between now and let's say the December meeting?",
#    'tokens': [51314,
#     1119,
#     257,
#     760,
#     47445,
#     27820,
#     317,
#     322,
#     257,
#     6798,
#     295,
#     1101,
#     15860,
#     1412,
#     4682,
#     1296,
#     586,
#     293,
#     718,
#     311,
#     584,
#     264,
#     7687,
#     3440,
#     30,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.12686357692796357,
#    'compression_ratio': 1.578740157480315,
#    'no_speech_prob': 0.12172262370586395},
#   {'id': 59,
#    'seek': 43100,
#    'start': 431.0,
#    'end': 439.0,
#    'text': ' Is that something that the Fed could potentially proceed with independent of that data given the lag defects that you mentioned?',
#    'tokens': [50364,
#     1119,
#     300,
#     746,
#     300,
#     264,
#     7772,
#     727,
#     7263,
#     8991,
#     365,
#     6695,
#     295,
#     300,
#     1412,
#     2212,
#     264,
#     8953,
#     32655,
#     300,
#     291,
#     2835,
#     30,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.1264847687312535,
#    'compression_ratio': 1.7370242214532872,
#    'no_speech_prob': 0.14459560811519623},
#   {'id': 60,
#    'seek': 43100,
#    'start': 439.0,
#    'end': 442.0,
#    'text': ' So a couple of things on that.',
#    'tokens': [50764, 407, 257, 1916, 295, 721, 322, 300, 13, 50914],
#    'temperature': 0.0,
#    'avg_logprob': -0.1264847687312535,
#    'compression_ratio': 1.7370242214532872,
#    'no_speech_prob': 0.14459560811519623},
#   {'id': 61,
#    'seek': 43100,
#    'start': 442.0,
#    'end': 449.0,
#    'text': ' We do need to see inflation coming down decisively and good at evidence of that would be a series of down monthly readings.',
#    'tokens': [50914,
#     492,
#     360,
#     643,
#     281,
#     536,
#     15860,
#     1348,
#     760,
#     18206,
#     3413,
#     293,
#     665,
#     412,
#     4467,
#     295,
#     300,
#     576,
#     312,
#     257,
#     2638,
#     295,
#     760,
#     12878,
#     27319,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.1264847687312535,
#    'compression_ratio': 1.7370242214532872,
#    'no_speech_prob': 0.14459560811519623},
#   {'id': 62,
#    'seek': 43100,
#    'start': 449.0,
#    'end': 451.0,
#    'text': " Of course that's what we'd all love to see.",
#    'tokens': [51264,
#     2720,
#     1164,
#     300,
#     311,
#     437,
#     321,
#     1116,
#     439,
#     959,
#     281,
#     536,
#     13,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.1264847687312535,
#    'compression_ratio': 1.7370242214532872,
#    'no_speech_prob': 0.14459560811519623},
#   {'id': 63,
#    'seek': 43100,
#    'start': 451.0,
#    'end': 460.0,
#    'text': " But that's, I've never thought of that as the appropriate test for slowing the pace of increases or for identifying the appropriately restrictive level that we're aiming for.",
#    'tokens': [51364,
#     583,
#     300,
#     311,
#     11,
#     286,
#     600,
#     1128,
#     1194,
#     295,
#     300,
#     382,
#     264,
#     6854,
#     1500,
#     337,
#     26958,
#     264,
#     11638,
#     295,
#     8637,
#     420,
#     337,
#     16696,
#     264,
#     23505,
#     43220,
#     1496,
#     300,
#     321,
#     434,
#     20253,
#     337,
#     13,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.1264847687312535,
#    'compression_ratio': 1.7370242214532872,
#    'no_speech_prob': 0.14459560811519623},
#   {'id': 64,
#    'seek': 46000,
#    'start': 460.0,
#    'end': 468.0,
#    'text': " We need to bring our policy stance down to a level that's sufficiently restrictive to bring inflation down to our 2% objective over the medium term.",
#    'tokens': [50364,
#     492,
#     643,
#     281,
#     1565,
#     527,
#     3897,
#     21033,
#     760,
#     281,
#     257,
#     1496,
#     300,
#     311,
#     31868,
#     43220,
#     281,
#     1565,
#     15860,
#     760,
#     281,
#     527,
#     568,
#     4,
#     10024,
#     670,
#     264,
#     6399,
#     1433,
#     13,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.0821494606305968,
#    'compression_ratio': 1.6767676767676767,
#    'no_speech_prob': 0.025090692564845085},
#   {'id': 65,
#    'seek': 46000,
#    'start': 468.0,
#    'end': 470.0,
#    'text': " How will we know that we've reached that level?",
#    'tokens': [50764,
#     1012,
#     486,
#     321,
#     458,
#     300,
#     321,
#     600,
#     6488,
#     300,
#     1496,
#     30,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.0821494606305968,
#    'compression_ratio': 1.6767676767676767,
#    'no_speech_prob': 0.025090692564845085},
#   {'id': 66,
#    'seek': 46000,
#    'start': 470.0,
#    'end': 483.0,
#    'text': " Well, we'll take into account the full range of analysis and data that bear on that question guided by our assessment of how much financial conditions have tightened the effects of that tightening is actually having on the real economy and on inflation.",
#    'tokens': [50864,
#     1042,
#     11,
#     321,
#     603,
#     747,
#     666,
#     2696,
#     264,
#     1577,
#     3613,
#     295,
#     5215,
#     293,
#     1412,
#     300,
#     6155,
#     322,
#     300,
#     1168,
#     19663,
#     538,
#     527,
#     9687,
#     295,
#     577,
#     709,
#     4669,
#     4487,
#     362,
#     49673,
#     264,
#     5065,
#     295,
#     300,
#     42217,
#     307,
#     767,
#     1419,
#     322,
#     264,
#     957,
#     5010,
#     293,
#     322,
#     15860,
#     13,
#     51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.0821494606305968,
#    'compression_ratio': 1.6767676767676767,
#    'no_speech_prob': 0.025090692564845085},
#   {'id': 67,
#    'seek': 46000,
#    'start': 483.0,
#    'end': 486.0,
#    'text': ' Taking into consideration lags, as I mentioned.',
#    'tokens': [51514,
#     17837,
#     666,
#     12381,
#     8953,
#     82,
#     11,
#     382,
#     286,
#     2835,
#     13,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.0821494606305968,
#    'compression_ratio': 1.6767676767676767,
#    'no_speech_prob': 0.025090692564845085},
#   {'id': 68,
#    'seek': 48600,
#    'start': 487.0,
#    'end': 493.0,
#    'text': ' We will be looking at real rates, for example, all across the yield curve and all other financial conditions.',
#    'tokens': [50414,
#     492,
#     486,
#     312,
#     1237,
#     412,
#     957,
#     6846,
#     11,
#     337,
#     1365,
#     11,
#     439,
#     2108,
#     264,
#     11257,
#     7605,
#     293,
#     439,
#     661,
#     4669,
#     4487,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 69,
#    'seek': 48600,
#    'start': 493.0,
#    'end': 496.0,
#    'text': ' And as we make that assessment.',
#    'tokens': [50714, 400, 382, 321, 652, 300, 9687, 13, 50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 70,
#    'seek': 48600,
#    'start': 496.0,
#    'end': 499.0,
#    'text': ' I would say.',
#    'tokens': [50864, 286, 576, 584, 13, 51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 71,
#    'seek': 48600,
#    'start': 499.0,
#    'end': 502.0,
#    'text': ' Hi, Howard Schneider with with Reuters.',
#    'tokens': [51014,
#     2421,
#     11,
#     17626,
#     30343,
#     1438,
#     365,
#     365,
#     1300,
#     48396,
#     13,
#     51164],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 72,
#    'seek': 48600,
#    'start': 502.0,
#    'end': 508.0,
#    'text': " Look, I'm sure there's going to be tons of confusion out there about whether this means you're going to slow in December or not.",
#    'tokens': [51164,
#     2053,
#     11,
#     286,
#     478,
#     988,
#     456,
#     311,
#     516,
#     281,
#     312,
#     9131,
#     295,
#     15075,
#     484,
#     456,
#     466,
#     1968,
#     341,
#     1355,
#     291,
#     434,
#     516,
#     281,
#     2964,
#     294,
#     7687,
#     420,
#     406,
#     13,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 73,
#    'seek': 48600,
#    'start': 508.0,
#    'end': 514.0,
#    'text': ' Would you say that the bias right now is not for another 75 basis point increase?',
#    'tokens': [51464,
#     6068,
#     291,
#     584,
#     300,
#     264,
#     12577,
#     558,
#     586,
#     307,
#     406,
#     337,
#     1071,
#     9562,
#     5143,
#     935,
#     3488,
#     30,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.17762998932773627,
#    'compression_ratio': 1.528301886792453,
#    'no_speech_prob': 0.12221197783946991},
#   {'id': 74,
#    'seek': 51400,
#    'start': 515.0,
#    'end': 526.0,
#    'text': ' What I want to do is put that question of pace in the context of our broader tightening program, if I may, and to talk about the statement language along the way.',
#    'tokens': [50414,
#     708,
#     286,
#     528,
#     281,
#     360,
#     307,
#     829,
#     300,
#     1168,
#     295,
#     11638,
#     294,
#     264,
#     4319,
#     295,
#     527,
#     13227,
#     42217,
#     1461,
#     11,
#     498,
#     286,
#     815,
#     11,
#     293,
#     281,
#     751,
#     466,
#     264,
#     5629,
#     2856,
#     2051,
#     264,
#     636,
#     13,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.12156848714809225,
#    'compression_ratio': 1.6929133858267718,
#    'no_speech_prob': 0.047969311475753784},
#   {'id': 75,
#    'seek': 51400,
#    'start': 526.0,
#    'end': 531.0,
#    'text': ' So I think you can think about our tightening program as really addressing three questions.',
#    'tokens': [50964,
#     407,
#     286,
#     519,
#     291,
#     393,
#     519,
#     466,
#     527,
#     42217,
#     1461,
#     382,
#     534,
#     14329,
#     1045,
#     1651,
#     13,
#     51214],
#    'temperature': 0.0,
#    'avg_logprob': -0.12156848714809225,
#    'compression_ratio': 1.6929133858267718,
#    'no_speech_prob': 0.047969311475753784},
#   {'id': 76,
#    'seek': 51400,
#    'start': 531.0,
#    'end': 534.0,
#    'text': ' The first of which was and has been how fast to go.',
#    'tokens': [51214,
#     440,
#     700,
#     295,
#     597,
#     390,
#     293,
#     575,
#     668,
#     577,
#     2370,
#     281,
#     352,
#     13,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.12156848714809225,
# ...
#    'no_speech_prob': 0.033514004200696945},
#   {'id': 541,
#    'seek': 259430,
#    'start': 2595.3,
#    'end': 2597.7000000000003,
#    'text': ' in the labor market is highly unusual,',
#    'tokens': [50414, 294, 264, 5938, 2142, 307, 5405, 10901, 11, 50534],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 542,
#    'seek': 259430,
#    'start': 2597.7000000000003,
#    'end': 2601.7000000000003,
#    'text': ' and to many economists, there is a path to,',
#    'tokens': [50534,
#     293,
#     281,
#     867,
#     32431,
#     11,
#     456,
#     307,
#     257,
#     3100,
#     281,
#     11,
#     50734],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 543,
#    'seek': 259430,
#    'start': 2602.7400000000002,
#    'end': 2606.34,
#    'text': " there's an ordinarial, there's a relationship to GEP",
#    'tokens': [50786,
#     456,
#     311,
#     364,
#     4792,
#     6470,
#     831,
#     11,
#     456,
#     311,
#     257,
#     2480,
#     281,
#     460,
#     8929,
#     50966],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 544,
#    'seek': 259430,
#    'start': 2606.34,
#    'end': 2610.98,
#    'text': ' going down and vacancies declining,',
#    'tokens': [50966, 516, 760, 293, 2842, 32286, 34298, 11, 51198],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 545,
#    'seek': 259430,
#    'start': 2610.98,
#    'end': 2614.46,
#    'text': " translating into unemployment, or there's Oaken's law.",
#    'tokens': [51198,
#     35030,
#     666,
#     17438,
#     11,
#     420,
#     456,
#     311,
#     422,
#     9846,
#     311,
#     2101,
#     13,
#     51372],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 546,
#    'seek': 259430,
#    'start': 2614.46,
#    'end': 2617.6200000000003,
#    'text': ' So all those things are relationships that are in the data',
#    'tokens': [51372,
#     407,
#     439,
#     729,
#     721,
#     366,
#     6159,
#     300,
#     366,
#     294,
#     264,
#     1412,
#     51530],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 547,
#    'seek': 259430,
#    'start': 2617.6200000000003,
#    'end': 2619.2200000000003,
#    'text': " and they're very real.",
#    'tokens': [51530, 293, 436, 434, 588, 957, 13, 51610],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 548,
#    'seek': 259430,
#    'start': 2619.2200000000003,
#    'end': 2620.54,
#    'text': " There's a little bit different this time though,",
#    'tokens': [51610, 821, 311, 257, 707, 857, 819, 341, 565, 1673, 11, 51676],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 549,
#    'seek': 259430,
#    'start': 2620.54,
#    'end': 2623.1000000000004,
#    'text': ' because you have this tremendously high level of vacancies',
#    'tokens': [51676,
#     570,
#     291,
#     362,
#     341,
#     27985,
#     1090,
#     1496,
#     295,
#     2842,
#     32286,
#     51804],
#    'temperature': 0.0,
#    'avg_logprob': -0.28792075060923167,
#    'compression_ratio': 1.6706827309236947,
#    'no_speech_prob': 0.021911880001425743},
#   {'id': 550,
#    'seek': 262310,
#    'start': 2623.14,
#    'end': 2626.98,
#    'text': ' and we think on a very steep part of the beverage curve,',
#    'tokens': [50366,
#     293,
#     321,
#     519,
#     322,
#     257,
#     588,
#     16841,
#     644,
#     295,
#     264,
#     35519,
#     7605,
#     11,
#     50558],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 551,
#    'seek': 262310,
#    'start': 2626.98,
#    'end': 2631.62,
#    'text': ' all I would say is that the job losses may turn out',
#    'tokens': [50558,
#     439,
#     286,
#     576,
#     584,
#     307,
#     300,
#     264,
#     1691,
#     15352,
#     815,
#     1261,
#     484,
#     50790],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 552,
#    'seek': 262310,
#    'start': 2631.62,
#    'end': 2635.74,
#    'text': ' to be less than would be indicated by those traditional measures',
#    'tokens': [50790,
#     281,
#     312,
#     1570,
#     813,
#     576,
#     312,
#     16176,
#     538,
#     729,
#     5164,
#     8000,
#     50996],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 553,
#    'seek': 262310,
#    'start': 2635.74,
#    'end': 2639.22,
#    'text': ' because job openings are so elevated',
#    'tokens': [50996, 570, 1691, 35941, 366, 370, 23457, 51170],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 554,
#    'seek': 262310,
#    'start': 2639.22,
#    'end': 2640.98,
#    'text': ' and because the labor market is so strong.',
#    'tokens': [51170, 293, 570, 264, 5938, 2142, 307, 370, 2068, 13, 51258],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 555,
#    'seek': 262310,
#    'start': 2642.18,
#    'end': 2644.98,
#    'text': " Again, that's gonna be something we discover empirically.",
#    'tokens': [51318,
#     3764,
#     11,
#     300,
#     311,
#     799,
#     312,
#     746,
#     321,
#     4411,
#     25790,
#     984,
#     13,
#     51458],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 556,
#    'seek': 262310,
#    'start': 2644.98,
#    'end': 2648.46,
#    'text': " I think no one knows whether there's gonna be a recession",
#    'tokens': [51458,
#     286,
#     519,
#     572,
#     472,
#     3255,
#     1968,
#     456,
#     311,
#     799,
#     312,
#     257,
#     24828,
#     51632],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 557,
#    'seek': 262310,
#    'start': 2648.46,
#    'end': 2652.5,
#    'text': ' or not, and if so, how bad that recession would be,',
#    'tokens': [51632,
#     420,
#     406,
#     11,
#     293,
#     498,
#     370,
#     11,
#     577,
#     1578,
#     300,
#     24828,
#     576,
#     312,
#     11,
#     51834],
#    'temperature': 0.0,
#    'avg_logprob': -0.14374617810519236,
#    'compression_ratio': 1.6772908366533865,
#    'no_speech_prob': 0.014240310527384281},
#   {'id': 558,
#    'seek': 265310,
#    'start': 2653.1,
#    'end': 2657.18,
#    'text': ' and our job is to restore price stability',
#    'tokens': [50364, 293, 527, 1691, 307, 281, 15227, 3218, 11826, 50568],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 559,
#    'seek': 265310,
#    'start': 2657.18,
#    'end': 2659.86,
#    'text': ' so that we can have a strong labor market',
#    'tokens': [50568, 370, 300, 321, 393, 362, 257, 2068, 5938, 2142, 50702],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 560,
#    'seek': 265310,
#    'start': 2659.86,
#    'end': 2662.2999999999997,
#    'text': " that benefits all over time, and that's what we're gonna do.",
#    'tokens': [50702,
#     300,
#     5311,
#     439,
#     670,
#     565,
#     11,
#     293,
#     300,
#     311,
#     437,
#     321,
#     434,
#     799,
#     360,
#     13,
#     50824],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 561,
#    'seek': 265310,
#    'start': 2662.2999999999997,
#    'end': 2664.54,
#    'text': ' It just real quickly, why do you feel like the window',
#    'tokens': [50824,
#     467,
#     445,
#     957,
#     2661,
#     11,
#     983,
#     360,
#     291,
#     841,
#     411,
#     264,
#     4910,
#     50936],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 562,
#    'seek': 265310,
#    'start': 2664.54,
#    'end': 2665.38,
#    'text': ' has narrowed?',
#    'tokens': [50936, 575, 9432, 292, 30, 50978],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 563,
#    'seek': 265310,
#    'start': 2667.38,
#    'end': 2670.9,
#    'text': " Because we haven't seen inflation coming down.",
#    'tokens': [51078, 1436, 321, 2378, 380, 1612, 15860, 1348, 760, 13, 51254],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 564,
#    'seek': 265310,
#    'start': 2670.9,
#    'end': 2673.8199999999997,
#    'text': ' The implication of inflation not coming down,',
#    'tokens': [51254, 440, 37814, 295, 15860, 406, 1348, 760, 11, 51400],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 565,
#    'seek': 265310,
#    'start': 2673.8199999999997,
#    'end': 2677.06,
#    'text': ' and what we would expect by now to have seen is that',
#    'tokens': [51400,
#     293,
#     437,
#     321,
#     576,
#     2066,
#     538,
#     586,
#     281,
#     362,
#     1612,
#     307,
#     300,
#     51562],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 566,
#    'seek': 265310,
#    'start': 2677.06,
#    'end': 2679.2599999999998,
#    'text': ' as the, really as a supply side,',
#    'tokens': [51562, 382, 264, 11, 534, 382, 257, 5847, 1252, 11, 51672],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 567,
#    'seek': 265310,
#    'start': 2679.2599999999998,
#    'end': 2682.2999999999997,
#    'text': ' problems had resolved themselves.',
#    'tokens': [51672, 2740, 632, 20772, 2969, 13, 51824],
#    'temperature': 0.0,
#    'avg_logprob': -0.2240314821226407,
#    'compression_ratio': 1.628352490421456,
#    'no_speech_prob': 0.0010636744555085897},
#   {'id': 568,
#    'seek': 268230,
#    'start': 2682.3,
#    'end': 2686.1800000000003,
#    'text': ' We would have expected goods inflation to come down by now,',
#    'tokens': [50364,
#     492,
#     576,
#     362,
#     5176,
#     10179,
#     15860,
#     281,
#     808,
#     760,
#     538,
#     586,
#     11,
#     50558],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 569,
#    'seek': 268230,
#    'start': 2686.1800000000003,
#    'end': 2688.5800000000004,
#    'text': " long since by now, and it really hasn't,",
#    'tokens': [50558,
#     938,
#     1670,
#     538,
#     586,
#     11,
#     293,
#     309,
#     534,
#     6132,
#     380,
#     11,
#     50678],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 570,
#    'seek': 268230,
#    'start': 2688.5800000000004,
#    'end': 2690.98,
#    'text': " although it's, actually it has come down,",
#    'tokens': [50678, 4878, 309, 311, 11, 767, 309, 575, 808, 760, 11, 50798],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 571,
#    'seek': 268230,
#    'start': 2690.98,
#    'end': 2693.2200000000003,
#    'text': " but it's not to the extent we had hoped.",
#    'tokens': [50798,
#     457,
#     309,
#     311,
#     406,
#     281,
#     264,
#     8396,
#     321,
#     632,
#     19737,
#     13,
#     50910],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 572,
#    'seek': 268230,
#    'start': 2693.2200000000003,
#    'end': 2695.6200000000003,
#    'text': ' At the same time, now you see services inflation,',
#    'tokens': [50910,
#     1711,
#     264,
#     912,
#     565,
#     11,
#     586,
#     291,
#     536,
#     3328,
#     15860,
#     11,
#     51030],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 573,
#    'seek': 268230,
#    'start': 2695.6200000000003,
#    'end': 2698.1000000000004,
#    'text': ' core services inflation moving up,',
#    'tokens': [51030, 4965, 3328, 15860, 2684, 493, 11, 51154],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 574,
#    'seek': 268230,
#    'start': 2698.1000000000004,
#    'end': 2701.6600000000003,
#    'text': ' and I just think that the inflation picture',
#    'tokens': [51154, 293, 286, 445, 519, 300, 264, 15860, 3036, 51332],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 575,
#    'seek': 268230,
#    'start': 2701.6600000000003,
#    'end': 2704.26,
#    'text': ' has become more and more challenging over the course',
#    'tokens': [51332, 575, 1813, 544, 293, 544, 7595, 670, 264, 1164, 51462],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 576,
#    'seek': 268230,
#    'start': 2704.26,
#    'end': 2706.02,
#    'text': ' of this year without question.',
#    'tokens': [51462, 295, 341, 1064, 1553, 1168, 13, 51550],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 577,
#    'seek': 268230,
#    'start': 2706.02,
#    'end': 2710.1800000000003,
#    'text': ' That means that we have to have policy be more restrictive',
#    'tokens': [51550,
#     663,
#     1355,
#     300,
#     321,
#     362,
#     281,
#     362,
#     3897,
#     312,
#     544,
#     43220,
#     51758],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 578,
#    'seek': 268230,
#    'start': 2710.1800000000003,
#    'end': 2712.0600000000004,
#    'text': ' and that narrows the path to a soft landing.',
#    'tokens': [51758,
#     293,
#     300,
#     6397,
#     1509,
#     264,
#     3100,
#     281,
#     257,
#     2787,
#     11202,
#     13,
#     51852],
#    'temperature': 0.0,
#    'avg_logprob': -0.13953404059776894,
#    'compression_ratio': 1.7857142857142858,
#    'no_speech_prob': 0.0015717209316790104},
#   {'id': 579,
#    'seek': 271206,
#    'start': 2712.06,
#    'end': 2713.54,
#    'text': ' That would say.',
#    'tokens': [50364, 663, 576, 584, 13, 50438],
#    'temperature': 0.0,
#    'avg_logprob': -0.48952656525831956,
#    'compression_ratio': 0.8048780487804879,
#    'no_speech_prob': 0.012387705966830254},
#   {'id': 580,
#    'seek': 271206,
#    'start': 2713.54,
#    'end': 2714.54,
#    'text': ' Thanks very much.',
#    'tokens': [50438, 2561, 588, 709, 13, 50488],
#    'temperature': 0.0,
#    'avg_logprob': -0.48952656525831956,
#    'compression_ratio': 0.8048780487804879,
#    'no_speech_prob': 0.012387705966830254}],
#  'language': 'en'}

# %%
output['text']
# Out:
# " Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal. We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses. Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy. Without price stability, the economy does not work for anyone. In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all. Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate. We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%. In addition, we are continuing the process of significantly reducing the size of our balance sheet. Restoring price stability will likely require maintaining a restrictive stance of policy for some time. I will have more to say about today's monetary policy actions after briefly reviewing economic developments. The U.S. economy has slowed significantly from last year's rapid pace. Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year. Recent indicators point to modest growth of spending and production this quarter. Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions. Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates. Higher interest rates and slower output growth also appear to be weighing on business fixed investment. Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low. Job vacancies still very high and wage growth elevated. Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September. Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers. The labor force participation rate is little changed since the beginning of the year. Inflation remains well above our longer run goal of 2%. Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%. And the recent inflation data again have come in higher than expected. Price pressures remained evident across a broad range of goods and services. Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation. Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters, as well as measures from financial markets. But that is not grounds for complacency. The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched. The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people. My colleagues and I are acutely aware that high inflation imposes significant hardship and as it erodes purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation. We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective. At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points. And we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in affirming the stance of monetary ...

# %%
for segment in output['segments']:
    print(segment)
    second = int(segment['start'])
    second = second - (second % 5)
    print(second)
# Out:
# {'id': 0, 'seek': 0, 'start': 0.0, 'end': 8.0, 'text': ' Good afternoon. My colleagues and I are strongly committed to bringing inflation back down to our 2% goal.', 'tokens': [50364, 2205, 6499, 13, 1222, 7734, 293, 286, 366, 10613, 7784, 281, 5062, 15860, 646, 760, 281, 527, 568, 4, 3387, 13, 50764], 'temperature': 0.0, 'avg_logprob': -0.14292316179017764, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247255206108093}
# 0
# {'id': 1, 'seek': 0, 'start': 8.0, 'end': 16.0, 'text': ' We have both the tools that we need and the resolve it will take to restore price stability on behalf of American families and businesses.', 'tokens': [50764, 492, 362, 1293, 264, 3873, 300, 321, 643, 293, 264, 14151, 309, 486, 747, 281, 15227, 3218, 11826, 322, 9490, 295, 2665, 4466, 293, 6011, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.14292316179017764, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247255206108093}
# 5
# {'id': 2, 'seek': 0, 'start': 16.0, 'end': 22.0, 'text': ' Price stability is the responsibility of the Federal Reserve and serves as the bedrock of our economy.', 'tokens': [51164, 25803, 11826, 307, 264, 6357, 295, 264, 12380, 26049, 293, 13451, 382, 264, 2901, 17799, 295, 527, 5010, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.14292316179017764, 'compression_ratio': 1.5818181818181818, 'no_speech_prob': 0.06247255206108093}
# 15
# {'id': 3, 'seek': 2200, 'start': 23.0, 'end': 26.0, 'text': ' Without price stability, the economy does not work for anyone.', 'tokens': [50414, 9129, 3218, 11826, 11, 264, 5010, 775, 406, 589, 337, 2878, 13, 50564], 'temperature': 0.0, 'avg_logprob': -0.09485793794904436, 'compression_ratio': 1.5251141552511416, 'no_speech_prob': 0.4874759614467621}
# 20
# {'id': 4, 'seek': 2200, 'start': 26.0, 'end': 34.0, 'text': ' In particular, without price stability, we will not achieve a sustained period of strong labor market conditions that benefit all.', 'tokens': [50564, 682, 1729, 11, 1553, 3218, 11826, 11, 321, 486, 406, 4584, 257, 23389, 2896, 295, 2068, 5938, 2142, 4487, 300, 5121, 439, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.09485793794904436, 'compression_ratio': 1.5251141552511416, 'no_speech_prob': 0.4874759614467621}
# 25
# {'id': 5, 'seek': 2200, 'start': 36.0, 'end': 45.0, 'text': ' Today, the FOMC raised our policy interest rate by 75 basis points and we continue to anticipate that ongoing increases will be appropriate.', 'tokens': [51064, 2692, 11, 264, 479, 5251, 34, 6005, 527, 3897, 1179, 3314, 538, 9562, 5143, 2793, 293, 321, 2354, 281, 21685, 300, 10452, 8637, 486, 312, 6854, 13, 51514], 'temperature': 0.0, 'avg_logprob': -0.09485793794904436, 'compression_ratio': 1.5251141552511416, 'no_speech_prob': 0.4874759614467621}
# 35
# {'id': 6, 'seek': 4500, 'start': 46.0, 'end': 52.0, 'text': ' We are moving our policy stance purposefully to a level that will be sufficiently restrictive to return inflation to 2%.', 'tokens': [50414, 492, 366, 2684, 527, 3897, 21033, 4334, 2277, 281, 257, 1496, 300, 486, 312, 31868, 43220, 281, 2736, 15860, 281, 568, 6856, 50714], 'temperature': 0.0, 'avg_logprob': -0.07955877079683192, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.2582671344280243}
# 45
# {'id': 7, 'seek': 4500, 'start': 52.0, 'end': 57.0, 'text': ' In addition, we are continuing the process of significantly reducing the size of our balance sheet.', 'tokens': [50714, 682, 4500, 11, 321, 366, 9289, 264, 1399, 295, 10591, 12245, 264, 2744, 295, 527, 4772, 8193, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.07955877079683192, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.2582671344280243}
# 50
# {'id': 8, 'seek': 4500, 'start': 57.0, 'end': 64.0, 'text': ' Restoring price stability will likely require maintaining a restrictive stance of policy for some time.', 'tokens': [50964, 13094, 3662, 3218, 11826, 486, 3700, 3651, 14916, 257, 43220, 21033, 295, 3897, 337, 512, 565, 13, 51314], 'temperature': 0.0, 'avg_logprob': -0.07955877079683192, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.2582671344280243}
# 55
# {'id': 9, 'seek': 4500, 'start': 64.0, 'end': 71.0, 'text': " I will have more to say about today's monetary policy actions after briefly reviewing economic developments.", 'tokens': [51314, 286, 486, 362, 544, 281, 584, 466, 965, 311, 26388, 3897, 5909, 934, 10515, 19576, 4836, 20862, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.07955877079683192, 'compression_ratio': 1.6526717557251909, 'no_speech_prob': 0.2582671344280243}
# 60
# {'id': 10, 'seek': 7100, 'start': 72.0, 'end': 77.0, 'text': " The U.S. economy has slowed significantly from last year's rapid pace.", 'tokens': [50414, 440, 624, 13, 50, 13, 5010, 575, 32057, 10591, 490, 1036, 1064, 311, 7558, 11638, 13, 50664], 'temperature': 0.0, 'avg_logprob': -0.10786630993797666, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.2946016490459442}
# 70
# {'id': 11, 'seek': 7100, 'start': 77.0, 'end': 84.0, 'text': ' Real GDP rose at a pace of 2.6% last quarter but is unchanged so far this year.', 'tokens': [50664, 8467, 19599, 10895, 412, 257, 11638, 295, 568, 13, 21, 4, 1036, 6555, 457, 307, 44553, 370, 1400, 341, 1064, 13, 51014], 'temperature': 0.0, 'avg_logprob': -0.10786630993797666, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.2946016490459442}
# 75
# {'id': 12, 'seek': 7100, 'start': 84.0, 'end': 89.0, 'text': ' Recent indicators point to modest growth of spending and production this quarter.', 'tokens': [51014, 17553, 22176, 935, 281, 25403, 4599, 295, 6434, 293, 4265, 341, 6555, 13, 51264], 'temperature': 0.0, 'avg_logprob': -0.10786630993797666, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.2946016490459442}
# 80
# {'id': 13, 'seek': 7100, 'start': 89.0, 'end': 98.0, 'text': " Growth in consumer spending has slowed from last year's rapid pace in part reflecting lower real disposable income and tighter financial conditions.", 'tokens': [51264, 48345, 294, 9711, 6434, 575, 32057, 490, 1036, 1064, 311, 7558, 11638, 294, 644, 23543, 3126, 957, 41578, 5742, 293, 30443, 4669, 4487, 13, 51714], 'temperature': 0.0, 'avg_logprob': -0.10786630993797666, 'compression_ratio': 1.6422413793103448, 'no_speech_prob': 0.2946016490459442}
# 85
# {'id': 14, 'seek': 9800, 'start': 99.0, 'end': 105.0, 'text': ' Activity in the housing sector has weakened significantly, largely reflecting higher mortgage rates.', 'tokens': [50414, 3251, 4253, 294, 264, 6849, 6977, 575, 42613, 10591, 11, 11611, 23543, 2946, 20236, 6846, 13, 50714], 'temperature': 0.0, 'avg_logprob': -0.13004178267258865, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.45754656195640564}
# 95
# {'id': 15, 'seek': 9800, 'start': 105.0, 'end': 112.0, 'text': ' Higher interest rates and slower output growth also appear to be weighing on business fixed investment.', 'tokens': [50714, 31997, 1179, 6846, 293, 14009, 5598, 4599, 611, 4204, 281, 312, 31986, 322, 1606, 6806, 6078, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.13004178267258865, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.45754656195640564}
# 105
# {'id': 16, 'seek': 9800, 'start': 112.0, 'end': 119.0, 'text': ' Despite the slowdown in growth, the labor market remains extremely tight with the unemployment rate at a 50-year low.', 'tokens': [51064, 11334, 264, 2964, 5093, 294, 4599, 11, 264, 5938, 2142, 7023, 4664, 4524, 365, 264, 17438, 3314, 412, 257, 2625, 12, 5294, 2295, 13, 51414], 'temperature': 0.0, 'avg_logprob': -0.13004178267258865, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.45754656195640564}
# 110
# {'id': 17, 'seek': 9800, 'start': 119.0, 'end': 124.0, 'text': ' Job vacancies still very high and wage growth elevated.', 'tokens': [51414, 18602, 2842, 32286, 920, 588, 1090, 293, 15444, 4599, 23457, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.13004178267258865, 'compression_ratio': 1.542857142857143, 'no_speech_prob': 0.45754656195640564}
# 115
# {'id': 18, 'seek': 12400, 'start': 125.0, 'end': 133.0, 'text': ' Job gains have been robust with employment rising by an average of 289,000 jobs per month over August and September.', 'tokens': [50414, 18602, 16823, 362, 668, 13956, 365, 11949, 11636, 538, 364, 4274, 295, 7562, 24, 11, 1360, 4782, 680, 1618, 670, 6897, 293, 7216, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.07048813716785328, 'compression_ratio': 1.5108225108225108, 'no_speech_prob': 0.05785762518644333}
# 125
# {'id': 19, 'seek': 12400, 'start': 133.0, 'end': 148.0, 'text': ' Although job vacancies have moved below their highs and the pace of job gains has slowed from earlier in the year, the labor market continues to be out of balance, with demand substantially exceeding the supply of available workers.', 'tokens': [50814, 5780, 1691, 2842, 32286, 362, 4259, 2507, 641, 29687, 293, 264, 11638, 295, 1691, 16823, 575, 32057, 490, 3071, 294, 264, 1064, 11, 264, 5938, 2142, 6515, 281, 312, 484, 295, 4772, 11, 365, 4733, 30797, 14048, 278, 264, 5847, 295, 2435, 5600, 13, 51564], 'temperature': 0.0, 'avg_logprob': -0.07048813716785328, 'compression_ratio': 1.5108225108225108, 'no_speech_prob': 0.05785762518644333}
# 130
# {'id': 20, 'seek': 14800, 'start': 148.0, 'end': 153.0, 'text': ' The labor force participation rate is little changed since the beginning of the year.', 'tokens': [50364, 440, 5938, 3464, 13487, 3314, 307, 707, 3105, 1670, 264, 2863, 295, 264, 1064, 13, 50614], 'temperature': 0.0, 'avg_logprob': -0.13766849040985107, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.43322715163230896}
# 145
# {'id': 21, 'seek': 14800, 'start': 153.0, 'end': 158.0, 'text': ' Inflation remains well above our longer run goal of 2%.', 'tokens': [50614, 682, 3423, 399, 7023, 731, 3673, 527, 2854, 1190, 3387, 295, 568, 6856, 50864], 'temperature': 0.0, 'avg_logprob': -0.13766849040985107, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.43322715163230896}
# 150
# {'id': 22, 'seek': 14800, 'start': 158.0, 'end': 169.0, 'text': ' Over the 12 months ending in September, total PCE prices rose at 6.2%, excluding the volatile food and energy categories, core PCE prices rose at 5.1%.', 'tokens': [50864, 4886, 264, 2272, 2493, 8121, 294, 7216, 11, 3217, 6465, 36, 7901, 10895, 412, 1386, 13, 17, 8923, 49999, 264, 34377, 1755, 293, 2281, 10479, 11, 4965, 6465, 36, 7901, 10895, 412, 1025, 13, 16, 6856, 51414], 'temperature': 0.0, 'avg_logprob': -0.13766849040985107, 'compression_ratio': 1.4577114427860696, 'no_speech_prob': 0.43322715163230896}
# 155
# {'id': 23, 'seek': 16900, 'start': 170.0, 'end': 174.0, 'text': ' And the recent inflation data again have come in higher than expected.', 'tokens': [50414, 400, 264, 5162, 15860, 1412, 797, 362, 808, 294, 2946, 813, 5176, 13, 50614], 'temperature': 0.0, 'avg_logprob': -0.10541546999753176, 'compression_ratio': 1.7056603773584906, 'no_speech_prob': 0.8328478932380676}
# 170
# {'id': 24, 'seek': 16900, 'start': 174.0, 'end': 178.0, 'text': ' Price pressures remained evident across a broad range of goods and services.', 'tokens': [50614, 25803, 23573, 12780, 16371, 2108, 257, 4152, 3613, 295, 10179, 293, 3328, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.10541546999753176, 'compression_ratio': 1.7056603773584906, 'no_speech_prob': 0.8328478932380676}
# 170
# {'id': 25, 'seek': 16900, 'start': 178.0, 'end': 186.0, 'text': " Russia's war against Ukraine has boosted prices for energy and food and has created additional upward pressure on inflation.", 'tokens': [50814, 6797, 311, 1516, 1970, 14081, 575, 9194, 292, 7901, 337, 2281, 293, 1755, 293, 575, 2942, 4497, 23452, 3321, 322, 15860, 13, 51214], 'temperature': 0.0, 'avg_logprob': -0.10541546999753176, 'compression_ratio': 1.7056603773584906, 'no_speech_prob': 0.8328478932380676}
# 175
# {'id': 26, 'seek': 16900, 'start': 186.0, 'end': 198.0, 'text': ' Despite elevated inflation, longer term inflation expectations appear to remain well anchored, as reflected in a broad range of surveys of households, businesses, and forecasters,', 'tokens': [51214, 11334, 23457, 15860, 11, 2854, 1433, 15860, 9843, 4204, 281, 6222, 731, 12723, 2769, 11, 382, 15502, 294, 257, 4152, 3613, 295, 22711, 295, 22850, 11, 6011, 11, 293, 2091, 16369, 1559, 11, 51814], 'temperature': 0.0, 'avg_logprob': -0.10541546999753176, 'compression_ratio': 1.7056603773584906, 'no_speech_prob': 0.8328478932380676}
# 185
# {'id': 27, 'seek': 19800, 'start': 198.0, 'end': 201.0, 'text': ' as well as measures from financial markets.', 'tokens': [50364, 382, 731, 382, 8000, 490, 4669, 8383, 13, 50514], 'temperature': 0.0, 'avg_logprob': -0.06573963165283203, 'compression_ratio': 1.5833333333333333, 'no_speech_prob': 0.12082453817129135}
# 195
# {'id': 28, 'seek': 19800, 'start': 201.0, 'end': 204.0, 'text': ' But that is not grounds for complacency.', 'tokens': [50514, 583, 300, 307, 406, 19196, 337, 49546, 3020, 13, 50664], 'temperature': 0.0, 'avg_logprob': -0.06573963165283203, 'compression_ratio': 1.5833333333333333, 'no_speech_prob': 0.12082453817129135}
# 200
# {'id': 29, 'seek': 19800, 'start': 204.0, 'end': 212.0, 'text': ' The longer the current amount of high inflation continues, the greater the chance that expectations of higher inflation will become entrenched.', 'tokens': [50664, 440, 2854, 264, 2190, 2372, 295, 1090, 15860, 6515, 11, 264, 5044, 264, 2931, 300, 9843, 295, 2946, 15860, 486, 1813, 948, 42388, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.06573963165283203, 'compression_ratio': 1.5833333333333333, 'no_speech_prob': 0.12082453817129135}
# 200
# {'id': 30, 'seek': 19800, 'start': 212.0, 'end': 220.0, 'text': " The Fed's monetary policy actions are guided by our mandate to promote maximum employment and stable prices for the American people.", 'tokens': [51064, 440, 7772, 311, 26388, 3897, 5909, 366, 19663, 538, 527, 23885, 281, 9773, 6674, 11949, 293, 8351, 7901, 337, 264, 2665, 561, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.06573963165283203, 'compression_ratio': 1.5833333333333333, 'no_speech_prob': 0.12082453817129135}
# 210
# {'id': 31, 'seek': 22000, 'start': 221.0, 'end': 235.0, 'text': ' My colleagues and I are acutely aware that high inflation imposes significant hardship and as it erodes purchasing power, especially for those least able to meet the higher costs of essentials like food, housing, and transportation.', 'tokens': [50414, 1222, 7734, 293, 286, 366, 696, 325, 736, 3650, 300, 1090, 15860, 704, 4201, 4776, 24172, 293, 382, 309, 1189, 4789, 20906, 1347, 11, 2318, 337, 729, 1935, 1075, 281, 1677, 264, 2946, 5497, 295, 46884, 411, 1755, 11, 6849, 11, 293, 11328, 13, 51114], 'temperature': 0.0, 'avg_logprob': -0.07810845607664527, 'compression_ratio': 1.6514522821576763, 'no_speech_prob': 0.36139461398124695}
# 220
# {'id': 32, 'seek': 22000, 'start': 235.0, 'end': 246.0, 'text': " We are highly attentive to the risks that high inflation poses to both sides of our mandate, and we're strongly committed to returning inflation to our 2% objective.", 'tokens': [51114, 492, 366, 5405, 43661, 281, 264, 10888, 300, 1090, 15860, 26059, 281, 1293, 4881, 295, 527, 23885, 11, 293, 321, 434, 10613, 7784, 281, 12678, 15860, 281, 527, 568, 4, 10024, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.07810845607664527, 'compression_ratio': 1.6514522821576763, 'no_speech_prob': 0.36139461398124695}
# 235
# {'id': 33, 'seek': 24600, 'start': 247.0, 'end': 253.0, 'text': " At today's meeting, the committee raised the target range for the federal funds rate by 75 basis points.", 'tokens': [50414, 1711, 965, 311, 3440, 11, 264, 7482, 6005, 264, 3779, 3613, 337, 264, 6019, 8271, 3314, 538, 9562, 5143, 2793, 13, 50714], 'temperature': 0.0, 'avg_logprob': -0.12230360507965088, 'compression_ratio': 1.5751072961373391, 'no_speech_prob': 0.4728427231311798}
# 245
# {'id': 34, 'seek': 24600, 'start': 253.0, 'end': 263.0, 'text': ' And we are continuing the process of significantly reducing the size of our balance sheet, which plays an important role in affirming the stance of monetary policy.', 'tokens': [50714, 400, 321, 366, 9289, 264, 1399, 295, 10591, 12245, 264, 2744, 295, 527, 4772, 8193, 11, 597, 5749, 364, 1021, 3090, 294, 36315, 2810, 264, 21033, 295, 26388, 3897, 13, 51214], 'temperature': 0.0, 'avg_logprob': -0.12230360507965088, 'compression_ratio': 1.5751072961373391, 'no_speech_prob': 0.4728427231311798}
# 250
# {'id': 35, 'seek': 24600, 'start': 263.0, 'end': 268.0, 'text': " With today's action, we've raised interest rates by 3 and 3-quarters percentage points this year.", 'tokens': [51214, 2022, 965, 311, 3069, 11, 321, 600, 6005, 1179, 6846, 538, 805, 293, 805, 12, 17313, 9668, 2793, 341, 1064, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.12230360507965088, 'compression_ratio': 1.5751072961373391, 'no_speech_prob': 0.4728427231311798}
# 260
# {'id': 36, 'seek': 26800, 'start': 268.0, 'end': 281.0, 'text': ' We anticipate that ongoing increases in the target range for the federal funds rate will be appropriate in order to attain a stance of monetary policy that is sufficiently restrictive to return inflation to 2% over time.', 'tokens': [50364, 492, 21685, 300, 10452, 8637, 294, 264, 3779, 3613, 337, 264, 6019, 8271, 3314, 486, 312, 6854, 294, 1668, 281, 23766, 257, 21033, 295, 26388, 3897, 300, 307, 31868, 43220, 281, 2736, 15860, 281, 568, 4, 670, 565, 13, 51014], 'temperature': 0.0, 'avg_logprob': -0.0632320761680603, 'compression_ratio': 1.6484375, 'no_speech_prob': 0.37917807698249817}
# 265
# {'id': 37, 'seek': 26800, 'start': 281.0, 'end': 291.0, 'text': ' Financial conditions have tightened significantly in response to our policy actions, and we are seeing the effects on demand in the most interest rate sensitive sectors of the economy, such as housing.', 'tokens': [51014, 25560, 4487, 362, 49673, 10591, 294, 4134, 281, 527, 3897, 5909, 11, 293, 321, 366, 2577, 264, 5065, 322, 4733, 294, 264, 881, 1179, 3314, 9477, 18373, 295, 264, 5010, 11, 1270, 382, 6849, 13, 51514], 'temperature': 0.0, 'avg_logprob': -0.0632320761680603, 'compression_ratio': 1.6484375, 'no_speech_prob': 0.37917807698249817}
# 280
# {'id': 38, 'seek': 29100, 'start': 292.0, 'end': 298.0, 'text': ' It will take time, however, for the full effects of monetary restraint to be realized, especially on inflation.', 'tokens': [50414, 467, 486, 747, 565, 11, 4461, 11, 337, 264, 1577, 5065, 295, 26388, 49281, 281, 312, 5334, 11, 2318, 322, 15860, 13, 50714], 'temperature': 0.0, 'avg_logprob': -0.056741231196635475, 'compression_ratio': 1.6727272727272726, 'no_speech_prob': 0.38531485199928284}
# 290
# {'id': 39, 'seek': 29100, 'start': 298.0, 'end': 312.0, 'text': " That's why we say in our statement that in determining the pace of future increases in the target range, we will take into account the cumulative tightening of monetary policy and the lags with which monetary policy affects economic activity and inflation.", 'tokens': [50714, 663, 311, 983, 321, 584, 294, 527, 5629, 300, 294, 23751, 264, 11638, 295, 2027, 8637, 294, 264, 3779, 3613, 11, 321, 486, 747, 666, 2696, 264, 38379, 42217, 295, 26388, 3897, 293, 264, 8953, 82, 365, 597, 26388, 3897, 11807, 4836, 5191, 293, 15860, 13, 51414], 'temperature': 0.0, 'avg_logprob': -0.056741231196635475, 'compression_ratio': 1.6727272727272726, 'no_speech_prob': 0.38531485199928284}
# 295
# {'id': 40, 'seek': 31200, 'start': 313.0, 'end': 326.0, 'text': " At some point, as I've said in the last two press conferences, it will become appropriate to slow the pace of increases as we approach the level of interest rates that will be sufficiently restrictive to bring inflation down to our 2% goal.", 'tokens': [50414, 1711, 512, 935, 11, 382, 286, 600, 848, 294, 264, 1036, 732, 1886, 22032, 11, 309, 486, 1813, 6854, 281, 2964, 264, 11638, 295, 8637, 382, 321, 3109, 264, 1496, 295, 1179, 6846, 300, 486, 312, 31868, 43220, 281, 1565, 15860, 760, 281, 527, 568, 4, 3387, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.06257445995624249, 'compression_ratio': 1.597938144329897, 'no_speech_prob': 0.6985467076301575}
# 310
# {'id': 41, 'seek': 31200, 'start': 326.0, 'end': 330.0, 'text': ' There is significant uncertainty around that level of interest rates.', 'tokens': [51064, 821, 307, 4776, 15697, 926, 300, 1496, 295, 1179, 6846, 13, 51264], 'temperature': 0.0, 'avg_logprob': -0.06257445995624249, 'compression_ratio': 1.597938144329897, 'no_speech_prob': 0.6985467076301575}
# 325
# {'id': 42, 'seek': 33000, 'start': 330.0, 'end': 342.0, 'text': ' Even so, we still have some ways to go, and incoming data since our last meeting suggests that the ultimate level of interest rates will be higher than previously expected.', 'tokens': [50364, 2754, 370, 11, 321, 920, 362, 512, 2098, 281, 352, 11, 293, 22341, 1412, 1670, 527, 1036, 3440, 13409, 300, 264, 9705, 1496, 295, 1179, 6846, 486, 312, 2946, 813, 8046, 5176, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.07905572293752647, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.6279720067977905}
# 330
# {'id': 43, 'seek': 33000, 'start': 342.0, 'end': 349.0, 'text': ' Our decisions will depend on the totality of incoming data and their implications for the outlook for economic activity and inflation.', 'tokens': [50964, 2621, 5327, 486, 5672, 322, 264, 1993, 1860, 295, 22341, 1412, 293, 641, 16602, 337, 264, 26650, 337, 4836, 5191, 293, 15860, 13, 51314], 'temperature': 0.0, 'avg_logprob': -0.07905572293752647, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.6279720067977905}
# 340
# {'id': 44, 'seek': 33000, 'start': 349.0, 'end': 354.0, 'text': ' We will continue to make our decisions meeting by being and communicate our thinking as clearly as possible.', 'tokens': [51314, 492, 486, 2354, 281, 652, 527, 5327, 3440, 538, 885, 293, 7890, 527, 1953, 382, 4448, 382, 1944, 13, 51564], 'temperature': 0.0, 'avg_logprob': -0.07905572293752647, 'compression_ratio': 1.7049180327868851, 'no_speech_prob': 0.6279720067977905}
# 345
# {'id': 45, 'seek': 35400, 'start': 355.0, 'end': 360.0, 'text': " We're taking forceful steps to moderate demand so that it comes into better alignment with supply.", 'tokens': [50414, 492, 434, 1940, 3464, 906, 4439, 281, 18174, 4733, 370, 300, 309, 1487, 666, 1101, 18515, 365, 5847, 13, 50664], 'temperature': 0.0, 'avg_logprob': -0.06982149051714547, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.5722406506538391}
# 355
# {'id': 46, 'seek': 35400, 'start': 360.0, 'end': 369.0, 'text': ' Our overarching focus is using our tools to bring inflation back down to our 2% goal and to keep longer term inflation expectations well anchored.', 'tokens': [50664, 2621, 45501, 1879, 307, 1228, 527, 3873, 281, 1565, 15860, 646, 760, 281, 527, 568, 4, 3387, 293, 281, 1066, 2854, 1433, 15860, 9843, 731, 12723, 2769, 13, 51114], 'temperature': 0.0, 'avg_logprob': -0.06982149051714547, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.5722406506538391}
# 360
# {'id': 47, 'seek': 35400, 'start': 369.0, 'end': 378.0, 'text': ' Reducing inflation is likely to require a sustained period of below trend growth and some softening of labor market conditions.', 'tokens': [51114, 4477, 1311, 278, 15860, 307, 3700, 281, 3651, 257, 23389, 2896, 295, 2507, 6028, 4599, 293, 512, 2787, 4559, 295, 5938, 2142, 4487, 13, 51564], 'temperature': 0.0, 'avg_logprob': -0.06982149051714547, 'compression_ratio': 1.5872340425531914, 'no_speech_prob': 0.5722406506538391}
# 365
# {'id': 48, 'seek': 37800, 'start': 379.0, 'end': 386.0, 'text': ' Restoring price stability is essential to set the stage for achieving maximum employment and stable prices in the longer run.', 'tokens': [50414, 13094, 3662, 3218, 11826, 307, 7115, 281, 992, 264, 3233, 337, 19626, 6674, 11949, 293, 8351, 7901, 294, 264, 2854, 1190, 13, 50764], 'temperature': 0.0, 'avg_logprob': -0.06328221573226753, 'compression_ratio': 1.6031128404669261, 'no_speech_prob': 0.7887825965881348}
# 375
# {'id': 49, 'seek': 37800, 'start': 386.0, 'end': 391.0, 'text': ' The historical record caution strongly against prematurely loosening policy.', 'tokens': [50764, 440, 8584, 2136, 23585, 10613, 1970, 34877, 356, 40454, 4559, 3897, 13, 51014], 'temperature': 0.0, 'avg_logprob': -0.06328221573226753, 'compression_ratio': 1.6031128404669261, 'no_speech_prob': 0.7887825965881348}
# 385
# {'id': 50, 'seek': 37800, 'start': 391.0, 'end': 394.0, 'text': ' We will stay the course until the job is done.', 'tokens': [51014, 492, 486, 1754, 264, 1164, 1826, 264, 1691, 307, 1096, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.06328221573226753, 'compression_ratio': 1.6031128404669261, 'no_speech_prob': 0.7887825965881348}
# 390
# {'id': 51, 'seek': 37800, 'start': 394.0, 'end': 400.0, 'text': ' To conclude, we understand that our actions affect communities, families, and businesses across the country.', 'tokens': [51164, 1407, 16886, 11, 321, 1223, 300, 527, 5909, 3345, 4456, 11, 4466, 11, 293, 6011, 2108, 264, 1941, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.06328221573226753, 'compression_ratio': 1.6031128404669261, 'no_speech_prob': 0.7887825965881348}
# 390
# {'id': 52, 'seek': 37800, 'start': 400.0, 'end': 404.0, 'text': ' Everything we do is in service to our public mission.', 'tokens': [51464, 5471, 321, 360, 307, 294, 2643, 281, 527, 1908, 4447, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.06328221573226753, 'compression_ratio': 1.6031128404669261, 'no_speech_prob': 0.7887825965881348}
# 400
# {'id': 53, 'seek': 40400, 'start': 405.0, 'end': 410.0, 'text': ' We at the Fed will do everything we can to achieve our maximum employment and price stability goals.', 'tokens': [50414, 492, 412, 264, 7772, 486, 360, 1203, 321, 393, 281, 4584, 527, 6674, 11949, 293, 3218, 11826, 5493, 13, 50664], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 405
# {'id': 54, 'seek': 40400, 'start': 410.0, 'end': 413.0, 'text': ' Thank you and I look forward to your questions.', 'tokens': [50664, 1044, 291, 293, 286, 574, 2128, 281, 428, 1651, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 410
# {'id': 55, 'seek': 40400, 'start': 413.0, 'end': 416.0, 'text': ' Thank you, Colby.', 'tokens': [50814, 1044, 291, 11, 4004, 2322, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 410
# {'id': 56, 'seek': 40400, 'start': 418.0, 'end': 420.0, 'text': ' Thank you, Colby Smith with the Financial Times.', 'tokens': [51064, 1044, 291, 11, 4004, 2322, 8538, 365, 264, 25560, 11366, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 415
# {'id': 57, 'seek': 40400, 'start': 420.0, 'end': 423.0, 'text': ' On the need to slow the pace of rate increases at some point.', 'tokens': [51164, 1282, 264, 643, 281, 2964, 264, 11638, 295, 3314, 8637, 412, 512, 935, 13, 51314], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 420
# {'id': 58, 'seek': 40400, 'start': 423.0, 'end': 431.0, 'text': " Is a downshift contingent on a string of better inflation data specifically between now and let's say the December meeting?", 'tokens': [51314, 1119, 257, 760, 47445, 27820, 317, 322, 257, 6798, 295, 1101, 15860, 1412, 4682, 1296, 586, 293, 718, 311, 584, 264, 7687, 3440, 30, 51714], 'temperature': 0.0, 'avg_logprob': -0.12686357692796357, 'compression_ratio': 1.578740157480315, 'no_speech_prob': 0.12172262370586395}
# 420
# {'id': 59, 'seek': 43100, 'start': 431.0, 'end': 439.0, 'text': ' Is that something that the Fed could potentially proceed with independent of that data given the lag defects that you mentioned?', 'tokens': [50364, 1119, 300, 746, 300, 264, 7772, 727, 7263, 8991, 365, 6695, 295, 300, 1412, 2212, 264, 8953, 32655, 300, 291, 2835, 30, 50764], 'temperature': 0.0, 'avg_logprob': -0.1264847687312535, 'compression_ratio': 1.7370242214532872, 'no_speech_prob': 0.14459560811519623}
# 430
# {'id': 60, 'seek': 43100, 'start': 439.0, 'end': 442.0, 'text': ' So a couple of things on that.', 'tokens': [50764, 407, 257, 1916, 295, 721, 322, 300, 13, 50914], 'temperature': 0.0, 'avg_logprob': -0.1264847687312535, 'compression_ratio': 1.7370242214532872, 'no_speech_prob': 0.14459560811519623}
# 435
# {'id': 61, 'seek': 43100, 'start': 442.0, 'end': 449.0, 'text': ' We do need to see inflation coming down decisively and good at evidence of that would be a series of down monthly readings.', 'tokens': [50914, 492, 360, 643, 281, 536, 15860, 1348, 760, 18206, 3413, 293, 665, 412, 4467, 295, 300, 576, 312, 257, 2638, 295, 760, 12878, 27319, 13, 51264], 'temperature': 0.0, 'avg_logprob': -0.1264847687312535, 'compression_ratio': 1.7370242214532872, 'no_speech_prob': 0.14459560811519623}
# 440
# {'id': 62, 'seek': 43100, 'start': 449.0, 'end': 451.0, 'text': " Of course that's what we'd all love to see.", 'tokens': [51264, 2720, 1164, 300, 311, 437, 321, 1116, 439, 959, 281, 536, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.1264847687312535, 'compression_ratio': 1.7370242214532872, 'no_speech_prob': 0.14459560811519623}
# 445
# {'id': 63, 'seek': 43100, 'start': 451.0, 'end': 460.0, 'text': " But that's, I've never thought of that as the appropriate test for slowing the pace of increases or for identifying the appropriately restrictive level that we're aiming for.", 'tokens': [51364, 583, 300, 311, 11, 286, 600, 1128, 1194, 295, 300, 382, 264, 6854, 1500, 337, 26958, 264, 11638, 295, 8637, 420, 337, 16696, 264, 23505, 43220, 1496, 300, 321, 434, 20253, 337, 13, 51814], 'temperature': 0.0, 'avg_logprob': -0.1264847687312535, 'compression_ratio': 1.7370242214532872, 'no_speech_prob': 0.14459560811519623}
# 450
# {'id': 64, 'seek': 46000, 'start': 460.0, 'end': 468.0, 'text': " We need to bring our policy stance down to a level that's sufficiently restrictive to bring inflation down to our 2% objective over the medium term.", 'tokens': [50364, 492, 643, 281, 1565, 527, 3897, 21033, 760, 281, 257, 1496, 300, 311, 31868, 43220, 281, 1565, 15860, 760, 281, 527, 568, 4, 10024, 670, 264, 6399, 1433, 13, 50764], 'temperature': 0.0, 'avg_logprob': -0.0821494606305968, 'compression_ratio': 1.6767676767676767, 'no_speech_prob': 0.025090692564845085}
# 460
# {'id': 65, 'seek': 46000, 'start': 468.0, 'end': 470.0, 'text': " How will we know that we've reached that level?", 'tokens': [50764, 1012, 486, 321, 458, 300, 321, 600, 6488, 300, 1496, 30, 50864], 'temperature': 0.0, 'avg_logprob': -0.0821494606305968, 'compression_ratio': 1.6767676767676767, 'no_speech_prob': 0.025090692564845085}
# 465
# {'id': 66, 'seek': 46000, 'start': 470.0, 'end': 483.0, 'text': " Well, we'll take into account the full range of analysis and data that bear on that question guided by our assessment of how much financial conditions have tightened the effects of that tightening is actually having on the real economy and on inflation.", 'tokens': [50864, 1042, 11, 321, 603, 747, 666, 2696, 264, 1577, 3613, 295, 5215, 293, 1412, 300, 6155, 322, 300, 1168, 19663, 538, 527, 9687, 295, 577, 709, 4669, 4487, 362, 49673, 264, 5065, 295, 300, 42217, 307, 767, 1419, 322, 264, 957, 5010, 293, 322, 15860, 13, 51514], 'temperature': 0.0, 'avg_logprob': -0.0821494606305968, 'compression_ratio': 1.6767676767676767, 'no_speech_prob': 0.025090692564845085}
# 470
# {'id': 67, 'seek': 46000, 'start': 483.0, 'end': 486.0, 'text': ' Taking into consideration lags, as I mentioned.', 'tokens': [51514, 17837, 666, 12381, 8953, 82, 11, 382, 286, 2835, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.0821494606305968, 'compression_ratio': 1.6767676767676767, 'no_speech_prob': 0.025090692564845085}
# 480
# {'id': 68, 'seek': 48600, 'start': 487.0, 'end': 493.0, 'text': ' We will be looking at real rates, for example, all across the yield curve and all other financial conditions.', 'tokens': [50414, 492, 486, 312, 1237, 412, 957, 6846, 11, 337, 1365, 11, 439, 2108, 264, 11257, 7605, 293, 439, 661, 4669, 4487, 13, 50714], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 485
# {'id': 69, 'seek': 48600, 'start': 493.0, 'end': 496.0, 'text': ' And as we make that assessment.', 'tokens': [50714, 400, 382, 321, 652, 300, 9687, 13, 50864], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 490
# {'id': 70, 'seek': 48600, 'start': 496.0, 'end': 499.0, 'text': ' I would say.', 'tokens': [50864, 286, 576, 584, 13, 51014], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 495
# {'id': 71, 'seek': 48600, 'start': 499.0, 'end': 502.0, 'text': ' Hi, Howard Schneider with with Reuters.', 'tokens': [51014, 2421, 11, 17626, 30343, 1438, 365, 365, 1300, 48396, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 495
# {'id': 72, 'seek': 48600, 'start': 502.0, 'end': 508.0, 'text': " Look, I'm sure there's going to be tons of confusion out there about whether this means you're going to slow in December or not.", 'tokens': [51164, 2053, 11, 286, 478, 988, 456, 311, 516, 281, 312, 9131, 295, 15075, 484, 456, 466, 1968, 341, 1355, 291, 434, 516, 281, 2964, 294, 7687, 420, 406, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 500
# {'id': 73, 'seek': 48600, 'start': 508.0, 'end': 514.0, 'text': ' Would you say that the bias right now is not for another 75 basis point increase?', 'tokens': [51464, 6068, 291, 584, 300, 264, 12577, 558, 586, 307, 406, 337, 1071, 9562, 5143, 935, 3488, 30, 51764], 'temperature': 0.0, 'avg_logprob': -0.17762998932773627, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.12221197783946991}
# 505
# {'id': 74, 'seek': 51400, 'start': 515.0, 'end': 526.0, 'text': ' What I want to do is put that question of pace in the context of our broader tightening program, if I may, and to talk about the statement language along the way.', 'tokens': [50414, 708, 286, 528, 281, 360, 307, 829, 300, 1168, 295, 11638, 294, 264, 4319, 295, 527, 13227, 42217, 1461, 11, 498, 286, 815, 11, 293, 281, 751, 466, 264, 5629, 2856, 2051, 264, 636, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.12156848714809225, 'compression_ratio': 1.6929133858267718, 'no_speech_prob': 0.047969311475753784}
# 515
# {'id': 75, 'seek': 51400, 'start': 526.0, 'end': 531.0, 'text': ' So I think you can think about our tightening program as really addressing three questions.', 'tokens': [50964, 407, 286, 519, 291, 393, 519, 466, 527, 42217, 1461, 382, 534, 14329, 1045, 1651, 13, 51214], 'temperature': 0.0, 'avg_logprob': -0.12156848714809225, 'compression_ratio': 1.6929133858267718, 'no_speech_prob': 0.047969311475753784}
# 525
# {'id': 76, 'seek': 51400, 'start': 531.0, 'end': 534.0, 'text': ' The first of which was and has been how fast to go.', 'tokens': [51214, 440, 700, 295, 597, 390, 293, 575, 668, 577, 2370, 281, 352, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.12156848714809225, 'compression_ratio': 1.6929133858267718, 'no_speech_prob': 0.047969311475753784}
# 530
# {'id': 77, 'seek': 51400, 'start': 534.0, 'end': 542.0, 'text': ' The second is how high to raise our policy rate and the third will be eventually how long to remain at a restrictive level.', 'tokens': [51364, 440, 1150, 307, 577, 1090, 281, 5300, 527, 3897, 3314, 293, 264, 2636, 486, 312, 4728, 577, 938, 281, 6222, 412, 257, 43220, 1496, 13, 51764], 'temperature': 0.0, 'avg_logprob': -0.12156848714809225, 'compression_ratio': 1.6929133858267718, 'no_speech_prob': 0.047969311475753784}
# 530
# {'id': 78, 'seek': 54200, 'start': 543.0, 'end': 546.0, 'text': ' On the first question, how fast to tighten policy.', 'tokens': [50414, 1282, 264, 700, 1168, 11, 577, 2370, 281, 17041, 3897, 13, 50564], 'temperature': 0.0, 'avg_logprob': -0.09980966460030034, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.06353466957807541}
# 540
# {'id': 79, 'seek': 54200, 'start': 546.0, 'end': 551.0, 'text': " It's been very important that we move expeditiously and we have clearly done so.", 'tokens': [50564, 467, 311, 668, 588, 1021, 300, 321, 1286, 19348, 270, 8994, 293, 321, 362, 4448, 1096, 370, 13, 50814], 'temperature': 0.0, 'avg_logprob': -0.09980966460030034, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.06353466957807541}
# 545
# {'id': 80, 'seek': 54200, 'start': 551.0, 'end': 556.0, 'text': " We've moved three and three quarters percent since March, admittedly from a base of zero.", 'tokens': [50814, 492, 600, 4259, 1045, 293, 1045, 20612, 3043, 1670, 6129, 11, 14920, 356, 490, 257, 3096, 295, 4018, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.09980966460030034, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.06353466957807541}
# 550
# {'id': 81, 'seek': 54200, 'start': 556.0, 'end': 564.0, 'text': " It's a historically fast pace and that's certainly appropriate given the persistence and strength and inflation and the low level from which we started.", 'tokens': [51064, 467, 311, 257, 16180, 2370, 11638, 293, 300, 311, 3297, 6854, 2212, 264, 37617, 293, 3800, 293, 15860, 293, 264, 2295, 1496, 490, 597, 321, 1409, 13, 51464], 'temperature': 0.0, 'avg_logprob': -0.09980966460030034, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.06353466957807541}
# 555
# {'id': 82, 'seek': 54200, 'start': 564.0, 'end': 568.0, 'text': ' So now we come to the second question, which is how high to raise our policy rate.', 'tokens': [51464, 407, 586, 321, 808, 281, 264, 1150, 1168, 11, 597, 307, 577, 1090, 281, 5300, 527, 3897, 3314, 13, 51664], 'temperature': 0.0, 'avg_logprob': -0.09980966460030034, 'compression_ratio': 1.667883211678832, 'no_speech_prob': 0.06353466957807541}
# 560
# {'id': 83, 'seek': 56800, 'start': 568.0, 'end': 575.0, 'text': " And we're saying that we'd raise that rate to a level that's sufficiently restrictive to bring inflation to our two percent target over time.", 'tokens': [50364, 400, 321, 434, 1566, 300, 321, 1116, 5300, 300, 3314, 281, 257, 1496, 300, 311, 31868, 43220, 281, 1565, 15860, 281, 527, 732, 3043, 3779, 670, 565, 13, 50714], 'temperature': 0.0, 'avg_logprob': -0.11021531669838915, 'compression_ratio': 1.7115384615384615, 'no_speech_prob': 0.24933432042598724}
# 565
# {'id': 84, 'seek': 56800, 'start': 575.0, 'end': 585.0, 'text': ' And we put that into our post meeting statement because that really does become the important question we think now is how far to go.', 'tokens': [50714, 400, 321, 829, 300, 666, 527, 2183, 3440, 5629, 570, 300, 534, 775, 1813, 264, 1021, 1168, 321, 519, 586, 307, 577, 1400, 281, 352, 13, 51214], 'temperature': 0.0, 'avg_logprob': -0.11021531669838915, 'compression_ratio': 1.7115384615384615, 'no_speech_prob': 0.24933432042598724}
# 575
# {'id': 85, 'seek': 56800, 'start': 585.0, 'end': 587.0, 'text': " And I'll talk more about that.", 'tokens': [51214, 400, 286, 603, 751, 544, 466, 300, 13, 51314], 'temperature': 0.0, 'avg_logprob': -0.11021531669838915, 'compression_ratio': 1.7115384615384615, 'no_speech_prob': 0.24933432042598724}
# 585
# {'id': 86, 'seek': 56800, 'start': 587.0, 'end': 589.0, 'text': " We think there's some ground to cover.", 'tokens': [51314, 492, 519, 456, 311, 512, 2727, 281, 2060, 13, 51414], 'temperature': 0.0, 'avg_logprob': -0.11021531669838915, 'compression_ratio': 1.7115384615384615, 'no_speech_prob': 0.24933432042598724}
# 585
# {'id': 87, 'seek': 56800, 'start': 589.0, 'end': 593.0, 'text': " But before we meet that test and that's why we say that ongoing rate increases will be appropriate.", 'tokens': [51414, 583, 949, 321, 1677, 300, 1500, 293, 300, 311, 983, 321, 584, 300, 10452, 3314, 8637, 486, 312, 6854, 13, 51614], 'temperature': 0.0, 'avg_logprob': -0.11021531669838915, 'compression_ratio': 1.7115384615384615, 'no_speech_prob': 0.24933432042598724}
# 585
# {'id': 88, 'seek': 59300, 'start': 594.0, 'end': 607.0, 'text': ' And as I mentioned, incoming data between the meetings, both the strong labor market report, but particularly the CPI report, do suggest to me that we may ultimately move to higher levels than we thought at the time of the September meeting.', 'tokens': [50414, 400, 382, 286, 2835, 11, 22341, 1412, 1296, 264, 8410, 11, 1293, 264, 2068, 5938, 2142, 2275, 11, 457, 4098, 264, 22431, 40, 2275, 11, 360, 3402, 281, 385, 300, 321, 815, 6284, 1286, 281, 2946, 4358, 813, 321, 1194, 412, 264, 565, 295, 264, 7216, 3440, 13, 51064], 'temperature': 0.0, 'avg_logprob': -0.10334362646546026, 'compression_ratio': 1.6264150943396227, 'no_speech_prob': 0.6514424681663513}
# 590
# {'id': 89, 'seek': 59300, 'start': 607.0, 'end': 614.0, 'text': " That level is very uncertain though and I would say, you know, we're going to find it over time.", 'tokens': [51064, 663, 1496, 307, 588, 11308, 1673, 293, 286, 576, 584, 11, 291, 458, 11, 321, 434, 516, 281, 915, 309, 670, 565, 13, 51414], 'temperature': 0.0, 'avg_logprob': -0.10334362646546026, 'compression_ratio': 1.6264150943396227, 'no_speech_prob': 0.6514424681663513}
# 605
# {'id': 90, 'seek': 59300, 'start': 614.0, 'end': 620.0, 'text': " Of course, with the lags between policy and economic activity, there's a lot of uncertainty.", 'tokens': [51414, 2720, 1164, 11, 365, 264, 8953, 82, 1296, 3897, 293, 4836, 5191, 11, 456, 311, 257, 688, 295, 15697, 13, 51714], 'temperature': 0.0, 'avg_logprob': -0.10334362646546026, 'compression_ratio': 1.6264150943396227, 'no_speech_prob': 0.6514424681663513}
# 610
# {'id': 91, 'seek': 62000, 'start': 620.0, 'end': 631.0, 'text': ' So we note that in determining the pace of future increases will take into account the cumulative tightening of monetary policy as well as the lags with monetary policy affects economic activity inflation.', 'tokens': [50364, 407, 321, 3637, 300, 294, 23751, 264, 11638, 295, 2027, 8637, 486, 747, 666, 2696, 264, 38379, 42217, 295, 26388, 3897, 382, 731, 382, 264, 8953, 82, 365, 26388, 3897, 11807, 4836, 5191, 15860, 13, 50914], 'temperature': 0.0, 'avg_logprob': -0.07717716580345517, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.08128657937049866}
# 620
# {'id': 92, 'seek': 62000, 'start': 631.0, 'end': 636.0, 'text': ' So I would say as we come closer to that level, move more into restrictive territory.', 'tokens': [50914, 407, 286, 576, 584, 382, 321, 808, 4966, 281, 300, 1496, 11, 1286, 544, 666, 43220, 11360, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.07717716580345517, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.08128657937049866}
# 630
# {'id': 93, 'seek': 62000, 'start': 636.0, 'end': 640.0, 'text': ' The question of speed becomes less important than the second and third questions.', 'tokens': [51164, 440, 1168, 295, 3073, 3643, 1570, 1021, 813, 264, 1150, 293, 2636, 1651, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.07717716580345517, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.08128657937049866}
# 635
# {'id': 94, 'seek': 62000, 'start': 640.0, 'end': 647.0, 'text': " And that's why I've said it the last two press conferences that at some point it will become appropriate to slow the pace of increases.", 'tokens': [51364, 400, 300, 311, 983, 286, 600, 848, 309, 264, 1036, 732, 1886, 22032, 300, 412, 512, 935, 309, 486, 1813, 6854, 281, 2964, 264, 11638, 295, 8637, 13, 51714], 'temperature': 0.0, 'avg_logprob': -0.07717716580345517, 'compression_ratio': 1.7431506849315068, 'no_speech_prob': 0.08128657937049866}
# 640
# {'id': 95, 'seek': 64700, 'start': 647.0, 'end': 652.0, 'text': ' So that time is coming and it may come as soon as the next meeting or the one after that.', 'tokens': [50364, 407, 300, 565, 307, 1348, 293, 309, 815, 808, 382, 2321, 382, 264, 958, 3440, 420, 264, 472, 934, 300, 13, 50614], 'temperature': 0.0, 'avg_logprob': -0.07412899350657047, 'compression_ratio': 1.7072243346007605, 'no_speech_prob': 0.03665061667561531}
# 645
# {'id': 96, 'seek': 64700, 'start': 652.0, 'end': 660.0, 'text': " No decision has been made. It is likely we'll have a discussion about this at the next meeting, a discussion.", 'tokens': [50614, 883, 3537, 575, 668, 1027, 13, 467, 307, 3700, 321, 603, 362, 257, 5017, 466, 341, 412, 264, 958, 3440, 11, 257, 5017, 13, 51014], 'temperature': 0.0, 'avg_logprob': -0.07412899350657047, 'compression_ratio': 1.7072243346007605, 'no_speech_prob': 0.03665061667561531}
# 650
# {'id': 97, 'seek': 64700, 'start': 660.0, 'end': 676.0, 'text': ' To be clear, let me say again, the question of when to moderate the pace of increases is now much less important than the question of how high to raise rates and how long to keep monetary policy restrictive, which really will be our principal focus.', 'tokens': [51014, 1407, 312, 1850, 11, 718, 385, 584, 797, 11, 264, 1168, 295, 562, 281, 18174, 264, 11638, 295, 8637, 307, 586, 709, 1570, 1021, 813, 264, 1168, 295, 577, 1090, 281, 5300, 6846, 293, 577, 938, 281, 1066, 26388, 3897, 43220, 11, 597, 534, 486, 312, 527, 9716, 1879, 13, 51814], 'temperature': 0.0, 'avg_logprob': -0.07412899350657047, 'compression_ratio': 1.7072243346007605, 'no_speech_prob': 0.03665061667561531}
# 660
# {'id': 98, 'seek': 67600, 'start': 676.0, 'end': 696.0, 'text': ' So I think I could follow up on that. To what degree was there an importance or weight given to a need to signal this possibility now given all the concerns really around the globe about fed policy sort of driving ahead and everybody else, you know, dealing with their own stress as a result.', 'tokens': [50364, 407, 286, 519, 286, 727, 1524, 493, 322, 300, 13, 1407, 437, 4314, 390, 456, 364, 7379, 420, 3364, 2212, 281, 257, 643, 281, 6358, 341, 7959, 586, 2212, 439, 264, 7389, 534, 926, 264, 15371, 466, 4636, 3897, 1333, 295, 4840, 2286, 293, 2201, 1646, 11, 291, 458, 11, 6260, 365, 641, 1065, 4244, 382, 257, 1874, 13, 51364], 'temperature': 0.0, 'avg_logprob': -0.18730057610405815, 'compression_ratio': 1.489795918367347, 'no_speech_prob': 0.31118330359458923}
# 675
# {'id': 99, 'seek': 69600, 'start': 696.0, 'end': 712.0, 'text': " I think I'm pleased that we have moved as fast as we have. I don't think we've over tightened. I think there's very difficult to make a case that our current level is too tight given that inflation still runs well above the federal funds rate.", 'tokens': [50364, 286, 519, 286, 478, 10587, 300, 321, 362, 4259, 382, 2370, 382, 321, 362, 13, 286, 500, 380, 519, 321, 600, 670, 49673, 13, 286, 519, 456, 311, 588, 2252, 281, 652, 257, 1389, 300, 527, 2190, 1496, 307, 886, 4524, 2212, 300, 15860, 920, 6676, 731, 3673, 264, 6019, 8271, 3314, 13, 51164], 'temperature': 0.0, 'avg_logprob': -0.09573492250944439, 'compression_ratio': 1.528301886792453, 'no_speech_prob': 0.3547278046607971}
# 695
# {'id': 100, 'seek': 71200, 'start': 712.0, 'end': 724.0, 'text': " So I think that at this meeting, the last two meetings, as I've mentioned, I've said that we that there would come a point and this was a meeting at which we had a discussion about what that might mean.", 'tokens': [50364, 407, 286, 519, 300, 412, 341, 3440, 11, 264, 1036, 732, 8410, 11, 382, 286, 600, 2835, 11, 286, 600, 848, 300, 321, 300, 456, 576, 808, 257, 935, 293, 341, 390, 257, 3440, 412, 597, 321, 632, 257, 5017, 466, 437, 300, 1062, 914, 13, 50964], 'temperature': 0.0, 'avg_logprob': -0.125197022825807, 'compression_ratio': 1.6944444444444444, 'no_speech_prob': 0.5870185494422913}
# 710
# ...
# 2570
# {'id': 535, 'seek': 256638, 'start': 2577.54, 'end': 2582.26, 'text': ' and stay higher for longer, it becomes harder to see the path.', 'tokens': [50922, 293, 1754, 2946, 337, 2854, 11, 309, 3643, 6081, 281, 536, 264, 3100, 13, 51158], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2575
# {'id': 536, 'seek': 256638, 'start': 2582.26, 'end': 2583.26, 'text': " It's narrowed.", 'tokens': [51158, 467, 311, 9432, 292, 13, 51208], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2580
# {'id': 537, 'seek': 256638, 'start': 2583.26, 'end': 2585.7000000000003, 'text': ' I would say the path is narrowed over the course of the last year,', 'tokens': [51208, 286, 576, 584, 264, 3100, 307, 9432, 292, 670, 264, 1164, 295, 264, 1036, 1064, 11, 51330], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2580
# {'id': 538, 'seek': 256638, 'start': 2585.7000000000003, 'end': 2586.7000000000003, 'text': ' really.', 'tokens': [51330, 534, 13, 51380], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2585
# {'id': 539, 'seek': 256638, 'start': 2586.7000000000003, 'end': 2589.3, 'text': ' Hard to say, hard to say.', 'tokens': [51380, 11817, 281, 584, 11, 1152, 281, 584, 13, 51510], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2585
# {'id': 540, 'seek': 256638, 'start': 2589.3, 'end': 2594.3, 'text': ' You know, again, I would say that the sort of array of data', 'tokens': [51510, 509, 458, 11, 797, 11, 286, 576, 584, 300, 264, 1333, 295, 10225, 295, 1412, 51760], 'temperature': 0.0, 'avg_logprob': -0.23351785056611413, 'compression_ratio': 1.6926406926406927, 'no_speech_prob': 0.033514004200696945}
# 2585
# {'id': 541, 'seek': 259430, 'start': 2595.3, 'end': 2597.7000000000003, 'text': ' in the labor market is highly unusual,', 'tokens': [50414, 294, 264, 5938, 2142, 307, 5405, 10901, 11, 50534], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2595
# {'id': 542, 'seek': 259430, 'start': 2597.7000000000003, 'end': 2601.7000000000003, 'text': ' and to many economists, there is a path to,', 'tokens': [50534, 293, 281, 867, 32431, 11, 456, 307, 257, 3100, 281, 11, 50734], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2595
# {'id': 543, 'seek': 259430, 'start': 2602.7400000000002, 'end': 2606.34, 'text': " there's an ordinarial, there's a relationship to GEP", 'tokens': [50786, 456, 311, 364, 4792, 6470, 831, 11, 456, 311, 257, 2480, 281, 460, 8929, 50966], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2600
# {'id': 544, 'seek': 259430, 'start': 2606.34, 'end': 2610.98, 'text': ' going down and vacancies declining,', 'tokens': [50966, 516, 760, 293, 2842, 32286, 34298, 11, 51198], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2605
# {'id': 545, 'seek': 259430, 'start': 2610.98, 'end': 2614.46, 'text': " translating into unemployment, or there's Oaken's law.", 'tokens': [51198, 35030, 666, 17438, 11, 420, 456, 311, 422, 9846, 311, 2101, 13, 51372], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2610
# {'id': 546, 'seek': 259430, 'start': 2614.46, 'end': 2617.6200000000003, 'text': ' So all those things are relationships that are in the data', 'tokens': [51372, 407, 439, 729, 721, 366, 6159, 300, 366, 294, 264, 1412, 51530], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2610
# {'id': 547, 'seek': 259430, 'start': 2617.6200000000003, 'end': 2619.2200000000003, 'text': " and they're very real.", 'tokens': [51530, 293, 436, 434, 588, 957, 13, 51610], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2615
# {'id': 548, 'seek': 259430, 'start': 2619.2200000000003, 'end': 2620.54, 'text': " There's a little bit different this time though,", 'tokens': [51610, 821, 311, 257, 707, 857, 819, 341, 565, 1673, 11, 51676], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2615
# {'id': 549, 'seek': 259430, 'start': 2620.54, 'end': 2623.1000000000004, 'text': ' because you have this tremendously high level of vacancies', 'tokens': [51676, 570, 291, 362, 341, 27985, 1090, 1496, 295, 2842, 32286, 51804], 'temperature': 0.0, 'avg_logprob': -0.28792075060923167, 'compression_ratio': 1.6706827309236947, 'no_speech_prob': 0.021911880001425743}
# 2620
# {'id': 550, 'seek': 262310, 'start': 2623.14, 'end': 2626.98, 'text': ' and we think on a very steep part of the beverage curve,', 'tokens': [50366, 293, 321, 519, 322, 257, 588, 16841, 644, 295, 264, 35519, 7605, 11, 50558], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2620
# {'id': 551, 'seek': 262310, 'start': 2626.98, 'end': 2631.62, 'text': ' all I would say is that the job losses may turn out', 'tokens': [50558, 439, 286, 576, 584, 307, 300, 264, 1691, 15352, 815, 1261, 484, 50790], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2625
# {'id': 552, 'seek': 262310, 'start': 2631.62, 'end': 2635.74, 'text': ' to be less than would be indicated by those traditional measures', 'tokens': [50790, 281, 312, 1570, 813, 576, 312, 16176, 538, 729, 5164, 8000, 50996], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2630
# {'id': 553, 'seek': 262310, 'start': 2635.74, 'end': 2639.22, 'text': ' because job openings are so elevated', 'tokens': [50996, 570, 1691, 35941, 366, 370, 23457, 51170], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2635
# {'id': 554, 'seek': 262310, 'start': 2639.22, 'end': 2640.98, 'text': ' and because the labor market is so strong.', 'tokens': [51170, 293, 570, 264, 5938, 2142, 307, 370, 2068, 13, 51258], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2635
# {'id': 555, 'seek': 262310, 'start': 2642.18, 'end': 2644.98, 'text': " Again, that's gonna be something we discover empirically.", 'tokens': [51318, 3764, 11, 300, 311, 799, 312, 746, 321, 4411, 25790, 984, 13, 51458], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2640
# {'id': 556, 'seek': 262310, 'start': 2644.98, 'end': 2648.46, 'text': " I think no one knows whether there's gonna be a recession", 'tokens': [51458, 286, 519, 572, 472, 3255, 1968, 456, 311, 799, 312, 257, 24828, 51632], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2640
# {'id': 557, 'seek': 262310, 'start': 2648.46, 'end': 2652.5, 'text': ' or not, and if so, how bad that recession would be,', 'tokens': [51632, 420, 406, 11, 293, 498, 370, 11, 577, 1578, 300, 24828, 576, 312, 11, 51834], 'temperature': 0.0, 'avg_logprob': -0.14374617810519236, 'compression_ratio': 1.6772908366533865, 'no_speech_prob': 0.014240310527384281}
# 2645
# {'id': 558, 'seek': 265310, 'start': 2653.1, 'end': 2657.18, 'text': ' and our job is to restore price stability', 'tokens': [50364, 293, 527, 1691, 307, 281, 15227, 3218, 11826, 50568], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2650
# {'id': 559, 'seek': 265310, 'start': 2657.18, 'end': 2659.86, 'text': ' so that we can have a strong labor market', 'tokens': [50568, 370, 300, 321, 393, 362, 257, 2068, 5938, 2142, 50702], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2655
# {'id': 560, 'seek': 265310, 'start': 2659.86, 'end': 2662.2999999999997, 'text': " that benefits all over time, and that's what we're gonna do.", 'tokens': [50702, 300, 5311, 439, 670, 565, 11, 293, 300, 311, 437, 321, 434, 799, 360, 13, 50824], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2655
# {'id': 561, 'seek': 265310, 'start': 2662.2999999999997, 'end': 2664.54, 'text': ' It just real quickly, why do you feel like the window', 'tokens': [50824, 467, 445, 957, 2661, 11, 983, 360, 291, 841, 411, 264, 4910, 50936], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2660
# {'id': 562, 'seek': 265310, 'start': 2664.54, 'end': 2665.38, 'text': ' has narrowed?', 'tokens': [50936, 575, 9432, 292, 30, 50978], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2660
# {'id': 563, 'seek': 265310, 'start': 2667.38, 'end': 2670.9, 'text': " Because we haven't seen inflation coming down.", 'tokens': [51078, 1436, 321, 2378, 380, 1612, 15860, 1348, 760, 13, 51254], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2665
# {'id': 564, 'seek': 265310, 'start': 2670.9, 'end': 2673.8199999999997, 'text': ' The implication of inflation not coming down,', 'tokens': [51254, 440, 37814, 295, 15860, 406, 1348, 760, 11, 51400], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2670
# {'id': 565, 'seek': 265310, 'start': 2673.8199999999997, 'end': 2677.06, 'text': ' and what we would expect by now to have seen is that', 'tokens': [51400, 293, 437, 321, 576, 2066, 538, 586, 281, 362, 1612, 307, 300, 51562], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2670
# {'id': 566, 'seek': 265310, 'start': 2677.06, 'end': 2679.2599999999998, 'text': ' as the, really as a supply side,', 'tokens': [51562, 382, 264, 11, 534, 382, 257, 5847, 1252, 11, 51672], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2675
# {'id': 567, 'seek': 265310, 'start': 2679.2599999999998, 'end': 2682.2999999999997, 'text': ' problems had resolved themselves.', 'tokens': [51672, 2740, 632, 20772, 2969, 13, 51824], 'temperature': 0.0, 'avg_logprob': -0.2240314821226407, 'compression_ratio': 1.628352490421456, 'no_speech_prob': 0.0010636744555085897}
# 2675
# {'id': 568, 'seek': 268230, 'start': 2682.3, 'end': 2686.1800000000003, 'text': ' We would have expected goods inflation to come down by now,', 'tokens': [50364, 492, 576, 362, 5176, 10179, 15860, 281, 808, 760, 538, 586, 11, 50558], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2680
# {'id': 569, 'seek': 268230, 'start': 2686.1800000000003, 'end': 2688.5800000000004, 'text': " long since by now, and it really hasn't,", 'tokens': [50558, 938, 1670, 538, 586, 11, 293, 309, 534, 6132, 380, 11, 50678], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2685
# {'id': 570, 'seek': 268230, 'start': 2688.5800000000004, 'end': 2690.98, 'text': " although it's, actually it has come down,", 'tokens': [50678, 4878, 309, 311, 11, 767, 309, 575, 808, 760, 11, 50798], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2685
# {'id': 571, 'seek': 268230, 'start': 2690.98, 'end': 2693.2200000000003, 'text': " but it's not to the extent we had hoped.", 'tokens': [50798, 457, 309, 311, 406, 281, 264, 8396, 321, 632, 19737, 13, 50910], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2690
# {'id': 572, 'seek': 268230, 'start': 2693.2200000000003, 'end': 2695.6200000000003, 'text': ' At the same time, now you see services inflation,', 'tokens': [50910, 1711, 264, 912, 565, 11, 586, 291, 536, 3328, 15860, 11, 51030], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2690
# {'id': 573, 'seek': 268230, 'start': 2695.6200000000003, 'end': 2698.1000000000004, 'text': ' core services inflation moving up,', 'tokens': [51030, 4965, 3328, 15860, 2684, 493, 11, 51154], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2695
# {'id': 574, 'seek': 268230, 'start': 2698.1000000000004, 'end': 2701.6600000000003, 'text': ' and I just think that the inflation picture', 'tokens': [51154, 293, 286, 445, 519, 300, 264, 15860, 3036, 51332], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2695
# {'id': 575, 'seek': 268230, 'start': 2701.6600000000003, 'end': 2704.26, 'text': ' has become more and more challenging over the course', 'tokens': [51332, 575, 1813, 544, 293, 544, 7595, 670, 264, 1164, 51462], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2700
# {'id': 576, 'seek': 268230, 'start': 2704.26, 'end': 2706.02, 'text': ' of this year without question.', 'tokens': [51462, 295, 341, 1064, 1553, 1168, 13, 51550], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2700
# {'id': 577, 'seek': 268230, 'start': 2706.02, 'end': 2710.1800000000003, 'text': ' That means that we have to have policy be more restrictive', 'tokens': [51550, 663, 1355, 300, 321, 362, 281, 362, 3897, 312, 544, 43220, 51758], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2705
# {'id': 578, 'seek': 268230, 'start': 2710.1800000000003, 'end': 2712.0600000000004, 'text': ' and that narrows the path to a soft landing.', 'tokens': [51758, 293, 300, 6397, 1509, 264, 3100, 281, 257, 2787, 11202, 13, 51852], 'temperature': 0.0, 'avg_logprob': -0.13953404059776894, 'compression_ratio': 1.7857142857142858, 'no_speech_prob': 0.0015717209316790104}
# 2710
# {'id': 579, 'seek': 271206, 'start': 2712.06, 'end': 2713.54, 'text': ' That would say.', 'tokens': [50364, 663, 576, 584, 13, 50438], 'temperature': 0.0, 'avg_logprob': -0.48952656525831956, 'compression_ratio': 0.8048780487804879, 'no_speech_prob': 0.012387705966830254}
# 2710
# {'id': 580, 'seek': 271206, 'start': 2713.54, 'end': 2714.54, 'text': ' Thanks very much.', 'tokens': [50438, 2561, 588, 709, 13, 50488], 'temperature': 0.0, 'avg_logprob': -0.48952656525831956, 'compression_ratio': 0.8048780487804879, 'no_speech_prob': 0.012387705966830254}
# 2710
